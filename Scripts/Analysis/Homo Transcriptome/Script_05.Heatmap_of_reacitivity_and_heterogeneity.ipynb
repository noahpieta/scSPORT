# %%
## loading package 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib import pylab
import seaborn as sns 
from sklearn.metrics.pairwise import cosine_similarity
from statannot import add_stat_annotation
import matplotlib as mpl
from scipy import stats, cluster
import glob
import re
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.stats import multitest
from matplotlib.gridspec import GridSpec

from matplotlib_venn import venn2, venn3
from matplotlib import pyplot as plt

import time
from scipy.stats.mstats import winsorize

import warnings 
warnings.simplefilter('ignore')

import random

## load_large_dataFrame
def load_large_dataFrame(input_file, sep=",", header=0, index_col=0, chunksize=100000, compressed=False):
    if compressed:
        TextFileReader = pd.read_csv(input_file, chunksize=chunksize, sep=sep, header=header,index_col=index_col, compression='gzip')
    else:
        TextFileReader = pd.read_csv(input_file, chunksize=chunksize, sep=sep, header=header,index_col=index_col)
    dfList=[]
    for df in TextFileReader:
        dfList.append(df)
    final_df = pd.concat(dfList,sort=False)
    return final_df

# %% [markdown]
# ## Heatmap of Reactivity and Heterogeneity (rsquare)
#     to answer the question of reviewer 2

# %% [markdown]
# ## 1. Prepare Data

# %%
## Retrieve mutrate matrix
b1_h9_mutrate = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt//neural_differentiation.mutrate_data/batch_1.h9.mutrate.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_h9_mutrate = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.h9.mutrate.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b1_day0_mutrate = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.day0.mutrate.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_day0_mutrate = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.day0.mutrate.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b1_day1_mutrate = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.day1.mutrate.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_day1_mutrate = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.day1.mutrate.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b1_day7_mutrate = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.day7.mutrate.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_day7_mutrate = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.day7.mutrate.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])

h9_mutrate = pd.concat([b1_h9_mutrate, b2_h9_mutrate], axis=1)
day0_mutrate = pd.concat([b1_day0_mutrate, b2_day0_mutrate], axis=1)
day1_mutrate = pd.concat([b1_day1_mutrate, b2_day1_mutrate], axis=1)
day7_mutrate = pd.concat([b1_day7_mutrate, b2_day7_mutrate], axis=1)

h9_mutrate = h9_mutrate.loc[h9_mutrate.isnull().sum(axis=1) < h9_mutrate.columns.size*0.5]
day0_mutrate = day0_mutrate.loc[day0_mutrate.isnull().sum(axis=1) < day0_mutrate.columns.size*0.5]
day1_mutrate = day1_mutrate.loc[day1_mutrate.isnull().sum(axis=1) < day1_mutrate.columns.size*0.5]
day7_mutrate = day7_mutrate.loc[day7_mutrate.isnull().sum(axis=1) < day7_mutrate.columns.size*0.5]

### add rRNAs
rRNA_df = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/all_cells.mutrate.rRNA.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
def add_rRNA_data(rRNA_df, df):
    df = df.loc[~df.index.get_level_values('gene').isin(['human_small', 'human_large'])]
    df = pd.concat([df, rRNA_df], join="inner")
    return df
h9_mutrate = add_rRNA_data(rRNA_df, h9_mutrate)
day0_mutrate = add_rRNA_data(rRNA_df, day0_mutrate)
day1_mutrate = add_rRNA_data(rRNA_df, day1_mutrate)
day7_mutrate = add_rRNA_data(rRNA_df, day7_mutrate)

mutrate_df = pd.concat([h9_mutrate, day0_mutrate, day1_mutrate, day7_mutrate], axis=1)
mutrate_df.loc[:, ~mutrate_df.columns.get_level_values('id').isin(['RHE1585', 'RHE1614','RHE1587','RHE1615','RHE1600','RHE1653','RHE1602','RHE1655','RHE1584'])]
mutrate_df = mutrate_df.xs('nai-n3', level="agent", axis=1, drop_level=False)

# %%
h9_mutrate = mutrate_df.xs('h9',level="stage", axis=1)
h9_mutrate
# Out:
# id            RHE1552   RHE1558   RHE1564   RHE1570 RHE1576 RHE1577 RHE1578  \
# batch         batch_1   batch_1   batch_1   batch_1 batch_1 batch_1 batch_1
# agent          nai-n3    nai-n3    nai-n3    nai-n3  nai-n3  nai-n3  nai-n3
# lib_type       single    single    single    single  single  single  single
# gene   pos
# AARS1  3160  0.002475  0.003272  0.009426  0.004772     NaN     NaN     NaN
#        3161  0.012346  0.015267  0.000855  0.007534     NaN     NaN     NaN
#        3162  0.000000  0.001095  0.004274  0.006845     NaN     NaN     NaN
#        3163  0.002433  0.000000  0.006838  0.007550     NaN     NaN     NaN
#        3164  0.007246  0.002181  0.002564  0.000682     NaN     NaN     NaN
# ...               ...       ...       ...       ...     ...     ...     ...
# TUBA1A 1004       NaN       NaN       NaN       NaN     NaN     NaN     NaN
#        1005       NaN       NaN       NaN       NaN     NaN     NaN     NaN
#        1006       NaN       NaN       NaN       NaN     NaN     NaN     NaN
#        1664       NaN       NaN       NaN       NaN     NaN     NaN     NaN
#        1665       NaN       NaN       NaN       NaN     NaN     NaN     NaN
#
# id          RHE1579   RHE1580 RHE1581  ...   RHS3587 RHS3588 RHS3589  \
# batch       batch_1   batch_1 batch_1  ...   batch_2 batch_2 batch_2
# agent        nai-n3    nai-n3  nai-n3  ...    nai-n3  nai-n3  nai-n3
# lib_type     single    single  single  ...    single  single  single
# gene   pos                             ...
# AARS1  3160     NaN  0.009238     NaN  ...  0.017613     NaN     NaN
#        3161     NaN  0.006928     NaN  ...  0.007905     NaN     NaN
#        3162     NaN  0.022936     NaN  ...  0.017787     NaN     NaN
#        3163     NaN  0.004566     NaN  ...  0.003937     NaN     NaN
#        3164     NaN  0.011390     NaN  ...  0.001946     NaN     NaN
# ...             ...       ...     ...  ...       ...     ...     ...
# TUBA1A 1004     NaN       NaN     NaN  ...       NaN     NaN     NaN
#        1005     NaN       NaN     NaN  ...       NaN     NaN     NaN
#        1006     NaN       NaN     NaN  ...       NaN     NaN     NaN
#        1664     NaN       NaN     NaN  ...       NaN     NaN     NaN
#        1665     NaN       NaN     NaN  ...       NaN     NaN     NaN
#
# id            RHS3590   RHS3591 RHS3592 RHS3593 RHS3594   RHS3595   RHS3596
# batch         batch_2   batch_2 batch_2 batch_2 batch_2   batch_2   batch_2
# agent          nai-n3    nai-n3  nai-n3  nai-n3  nai-n3    nai-n3    nai-n3
# lib_type       single    single  single  single  single    single    single
# gene   pos
# AARS1  3160  0.026275  0.023841     NaN     NaN     NaN  0.019934  0.017490
#        3161  0.040562  0.006623     NaN     NaN     NaN  0.016779  0.006192
#        3162  0.013997  0.005291     NaN     NaN     NaN  0.026846  0.003138
#        3163  0.006240  0.005326     NaN     NaN     NaN  0.010453  0.004167
#        3164  0.010853  0.005326     NaN     NaN     NaN  0.003460  0.007231
# ...               ...       ...     ...     ...     ...       ...       ...
# TUBA1A 1004       NaN       NaN     NaN     NaN     NaN       NaN       NaN
#        1005       NaN       NaN     NaN     NaN     NaN       NaN       NaN
#        1006       NaN       NaN     NaN     NaN     NaN       NaN       NaN
#        1664       NaN       NaN     NaN     NaN     NaN       NaN       NaN
#        1665       NaN       NaN     NaN     NaN     NaN       NaN       NaN
#
# [561568 rows x 76 columns]

# %%
crude_reac = load_large_dataFrame("../Current_Data/04.Wide_Reac_Matrix_1nt/neural_differentiate.stages.transcripts.crude_reac.csv",
                                      header=[0,1,2,3], index_col=[0,1])
gnorm_reac = load_large_dataFrame("../Current_Data/04.Wide_Reac_Matrix_1nt/neural_differentiate.stages.transcripts.gnorm_reac.csv",
                                      header=[0,1,2,3], index_col=[0,1])
crude_reac.loc[:, ~crude_reac.columns.get_level_values('id').isin(['RHE1585', 'RHE1614','RHE1587','RHE1615','RHE1600','RHE1653','RHE1602','RHE1655','RHE1584'])]
h9_crude_reac = crude_reac.xs('h9',level="stage", axis=1) #.xs('batch_1', level="batch", axis=1)
h9_gnorm_reac = gnorm_reac.xs('h9',level="stage", axis=1) #.xs('batch_1', level="batch", axis=1)

# %%
#bulk_reac = load_large_dataFrame("../Current_Data/04.Wide_Reac_Matrix_1nt/bulk2single.h9.transcripts.crude_reac.csv", header=[0,1,2,3], index_col=[0,1])
bulk_reac = load_large_dataFrame("../Current_Data/04.Wide_Reac_Matrix_1nt/bulk2single.h9.transcripts.gnorm_reac.csv", header=[0,1,2,3], index_col=[0,1])

bulk_reac = bulk_reac.loc[:, bulk_reac.columns.get_level_values('lib_type')!='single']
bulk_reac.columns = bulk_reac.columns.get_level_values('lib_type')
bulk_reac
# Out:
# lib_type       bulk      bulk   cell_10   cell_10   cell_10  cell_100  \
# gene pos
# A1BG 1401 -0.220289  0.168098  0.545629  0.000000  1.129234  0.562066
#      1402  0.083194  0.164167 -0.285977 -0.361010  0.295752  0.421550
#      1403 -0.190170 -0.229352 -0.697262 -0.898546 -0.895648 -0.069266
#      1404 -0.097319  0.076608 -0.291083 -0.367457  0.130158  0.859007
#      1405 -0.091042 -0.157409 -0.436625 -0.734914 -0.207155  0.284991
# ...             ...       ...       ...       ...       ...       ...
# ZYX  2153  0.342604  0.250636  0.171698  0.000000  0.000000       NaN
#      2154  0.000000  0.288523       NaN       NaN       NaN       NaN
#      2155 -0.434485  0.215681       NaN       NaN       NaN       NaN
#      2156 -0.084103  0.162003       NaN       NaN       NaN       NaN
#      2157  0.199487 -0.399936       NaN       NaN       NaN       NaN
#
# lib_type   cell_100  cell_100
# gene pos
# A1BG 1401  0.500343   0.00000
#      1402  0.000000   0.00000
#      1403 -0.280716  -0.26558
#      1404  0.000000   0.00000
#      1405  0.000000   0.00000
# ...             ...       ...
# ZYX  2153       NaN       NaN
#      2154       NaN       NaN
#      2155       NaN       NaN
#      2156       NaN       NaN
#      2157       NaN       NaN
#
# [1201991 rows x 8 columns]

# %%
crude_reac_10nt = load_large_dataFrame("../Current_Data/03.Wide_Reac_Matrix_10nt/neural_differentiate.stages.transcripts.crude_reac.10nt.csv",
                                      header=[0,1,2,3], index_col=[0,1])
h9_crude_reac_10nt = crude_reac_10nt.xs('h9',level="stage", axis=1)

# %%
wide_rsq_df = load_large_dataFrame("../Data/04.heterogeneity_dataframe/rsq.wide_matrix.Mut_vs_Cov.genome.1nt.annot.csv", index_col=[0,1,2,3,4,5,6,7,8], header=[0,1])
wide_rsq_df

rsq_df_10nt = load_large_dataFrame("../Data/04.heterogeneity_dataframe/rsq.Mut_vs_Cov.genome.10nt.stage.csv", index_col=None)
rsq_df_10nt['rsq'] = np.power(rsq_df_10nt['r'], 2)
wide_rsq_df_10nt = rsq_df_10nt.pivot(index=['gene','pos'], columns='stage', values='rsq')
wide_rsq_df_10nt
# Out:
# stage                 day0      day1      day7        h9
# gene        pos
# AARS1       3160       NaN       NaN       NaN  0.056084
#             3170       NaN       NaN       NaN  0.350402
#             3180       NaN       NaN       NaN  0.514118
#             3190       NaN       NaN       NaN  0.718837
#             3200       NaN       NaN       NaN  0.322359
# ...                    ...       ...       ...       ...
# human_small 1820  0.030697  0.001031  0.143579  0.018158
#             1830  0.232841  0.285384  0.320444  0.098702
#             1840  0.138200  0.011382  0.196235  0.333684
#             1850  0.057112  0.189784  0.239388  0.335851
#             1860  0.471151  0.470191  0.065084  0.517883
#
# [56069 rows x 4 columns]

# %%
wide_rsq_df.dropna()
# Out:
# batch              batch_1                                 batch_2            \
# stage                 day0      day1      day7        h9      day0      day1
# gene        pos
# AC011447.3  1641  0.551751  0.207989  0.225316  0.287949  0.533453  0.000642
#             1642  0.546838  0.605747  0.053444  0.040561  0.360133  0.382611
#             1643  0.508330  0.028746  0.335965  0.058904  0.096770  0.452665
#             1644  0.745950  0.415690  0.318179  0.209275  0.335325  0.537453
#             1645  0.350808  0.320757  0.358351  0.484905  0.121667  0.552553
# ...                    ...       ...       ...       ...       ...       ...
# human_small 1866  0.515769  0.700049  0.833442  0.822981  0.356102  0.525330
#             1867  0.586221  0.617221  0.741459  0.966736  0.747014  0.512077
#             1868  0.727247  0.803772  0.685847  0.912938  0.719111  0.596047
#             1869  0.743982  0.720285  0.677688  0.940725  0.693261  0.580685
#             1870  0.971789  0.995001  0.979199  0.996396  0.972004  0.960175
#
# batch
# stage                 day7        h9
# gene        pos
# AC011447.3  1641  0.259004  0.136837
#             1642  0.035508  0.168387
#             1643  0.243175  0.060865
#             1644  0.302248  0.049206
#             1645  0.568625  0.328322
# ...                    ...       ...
# human_small 1866  0.720521  0.797704
#             1867  0.567624  0.895338
#             1868  0.594926  0.721215
#             1869  0.497781  0.734293
#             1870  0.978599  0.974076
#
# [45988 rows x 8 columns]

# %%
#sns.kdeplot(data=rsq_df_10nt.loc[rsq_df_10nt['stage']=="h9"], x="rsq")
#sns.kdeplot(data=wide_rsq_df_10nt.dropna(), x="h9")
sns.kdeplot(data=wide_rsq_df.dropna(), x=("batch_1","h9"))
plt.show()
np.percentile(wide_rsq_df.dropna()[("batch_1","h9")], 95)
# Out:
# 0.8076315885703207

# %%
rsq_df = load_large_dataFrame("../Data/04.heterogeneity_dataframe/rsq.Mut_vs_Cov.genome.1nt..more5cells.remove_tenichreps.csv", header=[0], index_col=[0,1])
rsq_df['rsq'] = np.power(rsq_df['r'],2)
wide_rsq_df = rsq_df.reset_index().pivot(index=['gene','pos'], columns=['batch','stage'], values='rsq')
wide_rsq_df
# Out:
# batch              batch_1                                 batch_2            \
# stage                 day0      day1      day7        h9      day0      day1
# gene        pos
# AARS1       3058       NaN       NaN       NaN  0.728895       NaN       NaN
#             3059       NaN       NaN       NaN  0.003001       NaN       NaN
#             3060       NaN       NaN       NaN  0.862007       NaN       NaN
#             3061       NaN       NaN       NaN  0.438248       NaN       NaN
#             3062       NaN       NaN       NaN  0.393973       NaN       NaN
# ...                    ...       ...       ...       ...       ...       ...
# human_small 1866  0.515769  0.700049  0.833442  0.822981  0.356102  0.525330
#             1867  0.586221  0.617221  0.741459  0.966736  0.747014  0.512077
#             1868  0.727247  0.803772  0.685847  0.912938  0.719111  0.596047
#             1869  0.743982  0.720285  0.677688  0.940725  0.693261  0.580685
#             1870  0.971789  0.995001  0.979199  0.996396  0.972004  0.960175
#
# batch
# stage                 day7        h9
# gene        pos
# AARS1       3058       NaN  0.546097
#             3059       NaN  0.003493
#             3060       NaN  0.047360
#             3061       NaN  0.190307
#             3062       NaN  0.693062
# ...                    ...       ...
# human_small 1866  0.720521  0.797704
#             1867  0.567624  0.895338
#             1868  0.594926  0.721215
#             1869  0.497781  0.734293
#             1870  0.978599  0.974076
#
# [597798 rows x 8 columns]

# %%
np.percentile(rsq_df.loc[(rsq_df['batch']=="batch_1")&(rsq_df['stage']=="h9"),'rsq'], 95)
# Out:
# 0.741685473685938

# %%
h9_gnorm_reac.loc[h9_gnorm_reac.index.isin(rsq_df.loc[(rsq_df['batch']=="batch_1")&(rsq_df['stage']=="h9")&(rsq_df['rsq']>=0.75)].index)].dropna(how="any", thresh=0.5*h9_gnorm_reac.columns.size)
# Out:
# id                         RHE1552   RHE1558   RHE1564   RHE1570   RHE1576  \
# batch                      batch_1   batch_1   batch_1   batch_1   batch_1
# lib_type                    single    single    single    single    single
# id      batch   lib_type
# RHE1552 batch_1 single    1.000000  0.160932  0.231232  0.134186  0.220437
# RHE1558 batch_1 single    0.160932  1.000000  0.169638  0.082786  0.082077
# RHE1564 batch_1 single    0.231232  0.169638  1.000000  0.163966  0.214187
# RHE1570 batch_1 single    0.134186  0.082786  0.163966  1.000000  0.091496
# RHE1576 batch_1 single    0.220437  0.082077  0.214187  0.091496  1.000000
# ...                            ...       ...       ...       ...       ...
# RHS3592 batch_2 single    0.014256  0.092617  0.018065  0.020645  0.063407
# RHS3593 batch_2 single    0.149926  0.029546  0.030603  0.021209  0.055462
# RHS3594 batch_2 single    0.002129  0.007379  0.023953  0.015429  0.023765
# RHS3595 batch_2 single    0.006920  0.018035  0.027408  0.016854  0.024348
# RHS3596 batch_2 single    0.016016  0.014035  0.040289  0.024821  0.079661
#
# id                         RHE1577   RHE1578   RHE1579   RHE1580   RHE1581  \
# batch                      batch_1   batch_1   batch_1   batch_1   batch_1
# lib_type                    single    single    single    single    single
# id      batch   lib_type
# RHE1552 batch_1 single    0.206534  0.319804  0.233236  0.267942  0.235842
# RHE1558 batch_1 single    0.132435  0.342757  0.260758  0.301154  0.141558
# RHE1564 batch_1 single    0.238391  0.229863  0.253192  0.276518  0.229458
# RHE1570 batch_1 single    0.112550  0.084818  0.122113  0.152972  0.150367
# RHE1576 batch_1 single    0.271675  0.239397  0.211784  0.288018  0.333662
# ...                            ...       ...       ...       ...       ...
# RHS3592 batch_2 single    0.049111  0.079466  0.040184  0.063768  0.066702
# RHS3593 batch_2 single    0.045876  0.046151  0.062747  0.071418  0.061533
# RHS3594 batch_2 single    0.061778  0.021393  0.014470  0.025677  0.010276
# RHS3595 batch_2 single    0.048009  0.040636  0.073023  0.057208  0.036044
# RHS3596 batch_2 single    0.061097  0.045676  0.014812  0.034049  0.029934
#
# id                        ...   RHS3587   RHS3588   RHS3589   RHS3590  \
# batch                     ...   batch_2   batch_2   batch_2   batch_2
# lib_type                  ...    single    single    single    single
# id      batch   lib_type  ...
# RHE1552 batch_1 single    ...  0.033564  0.051333  0.013216  0.009941
# RHE1558 batch_1 single    ... -0.011026  0.009050  0.023646  0.039484
# RHE1564 batch_1 single    ...  0.037209  0.038707  0.009488  0.026340
# RHE1570 batch_1 single    ...  0.034076  0.012951  0.002020  0.022979
# RHE1576 batch_1 single    ...  0.044577  0.067963  0.039759  0.036796
# ...                       ...       ...       ...       ...       ...
# RHS3592 batch_2 single    ...  0.048103  0.038472  0.034268  0.045785
# RHS3593 batch_2 single    ...  0.047814  0.047668  0.024829  0.124883
# RHS3594 batch_2 single    ...  0.042444  0.072575  0.014532  0.031125
# RHS3595 batch_2 single    ...  0.056296  0.032344  0.063669  0.068494
# RHS3596 batch_2 single    ...  0.036079  0.044889  0.034986  0.054266
#
# id                         RHS3591   RHS3592   RHS3593   RHS3594   RHS3595  \
# batch                      batch_2   batch_2   batch_2   batch_2   batch_2
# lib_type                    single    single    single    single    single
# id      batch   lib_type
# RHE1552 batch_1 single    0.021235  0.014256  0.149926  0.002129  0.006920
# RHE1558 batch_1 single    0.026257  0.092617  0.029546  0.007379  0.018035
# RHE1564 batch_1 single    0.035757  0.018065  0.030603  0.023953  0.027408
# RHE1570 batch_1 single    0.007403  0.020645  0.021209  0.015429  0.016854
# RHE1576 batch_1 single    0.043322  0.063407  0.055462  0.023765  0.024348
# ...                            ...       ...       ...       ...       ...
# RHS3592 batch_2 single    0.045362  1.000000  0.030425  0.022479  0.034187
# RHS3593 batch_2 single    0.035748  0.030425  1.000000  0.041076  0.052039
# RHS3594 batch_2 single    0.025348  0.022479  0.041076  1.000000  0.031780
# RHS3595 batch_2 single    0.053925  0.034187  0.052039  0.031780  1.000000
# RHS3596 batch_2 single    0.030835  0.057890  0.044146  0.035986  0.075073
#
# id                         RHS3596
# batch                      batch_2
# lib_type                    single
# id      batch   lib_type
# RHE1552 batch_1 single    0.016016
# RHE1558 batch_1 single    0.014035
# RHE1564 batch_1 single    0.040289
# RHE1570 batch_1 single    0.024821
# RHE1576 batch_1 single    0.079661
# ...                            ...
# RHS3592 batch_2 single    0.057890
# RHS3593 batch_2 single    0.044146
# RHS3594 batch_2 single    0.035986
# RHS3595 batch_2 single    0.075073
# RHS3596 batch_2 single    1.000000
#
# [76 rows x 76 columns]

# %%
#h9_mosthomo_gnorm_reac = gnorm_reac.loc[gnorm_reac.index.isin(rsq_df.loc[(rsq_df['batch']=="batch_1")&(rsq_df['stage']=="h9")&(rsq_df['rsq']>=0.75),'rsq'].index), 
#                                       (gnorm_reac.columns.get_level_values('batch')=="batch_1")&(gnorm_reac.columns.get_level_values('stage')=="h9")]

temp_rsq = wide_rsq_df.dropna()[("batch_1","h9")]

fig, ax = plt.subplots(1,1, figsize=(4,4))

for threshold in [0.5,0.6,0.7,0.8,0.9]:
    bulk_mosthomo_reac = bulk_reac.loc[bulk_reac.index.isin(temp_rsq.loc[temp_rsq>threshold].index)]
    bulk_mosthomo_reac

    h9_mosthomo_reac = h9_crude_reac.loc[h9_crude_reac.index.isin(temp_rsq.loc[temp_rsq>threshold].index)]
    
    print (bulk_mosthomo_reac.index.size, h9_mosthomo_reac.index.size)
    bulk2h9_intersection = h9_mosthomo_reac.index.intersection(bulk_mosthomo_reac.index)

    h9_mosthomo_reac = h9_mosthomo_reac.loc[bulk2h9_intersection].sort_index()
    bulk_mosthomo_reac = bulk_mosthomo_reac.loc[bulk2h9_intersection].sort_index()
    bulk_mosthomo_reac = bulk_mosthomo_reac.iloc[:,[0,1]].mean(axis=1)
    bulk_mosthomo_reac

    sns.kdeplot(h9_mosthomo_reac.corrwith(bulk_mosthomo_reac), ax=ax, label=threshold)
plt.legend()
plt.show()
# Out:
# 5661 8056
# 3419 5591
# 1754 3727
# 606 2364
# 91 1488

# %% [markdown]
# #### 1,x

# %%
bulk2single_reac_rRNA = load_large_dataFrame("../Current_Data/04.Wide_Reac_Matrix_1nt/bulk2single.h9.rRNA.gnorm_reac.csv", header=[0,1,2,3], index_col=[0,1])
bulk2single_reac = load_large_dataFrame("../Current_Data/04.Wide_Reac_Matrix_1nt/bulk2single.h9.transcripts.gnorm_reac.csv", header=[0,1,2,3], index_col=[0,1])

bulk2single_reac = bulk2single_reac.loc[bulk2single_reac.index.get_level_values('gene')!="human_small"]
bulk2single_reac = pd.concat([bulk2single_reac, bulk2single_reac_rRNA])
bulk2single_reac = bulk2single_reac.xs('batch_1', level="batch", axis=1)


bulk2single_reac_single = bulk2single_reac.xs('single', level="lib_type", axis=1, drop_level=False)
bulk2single_reac_bulk = bulk2single_reac.xs('bulk', level="lib_type", axis=1, drop_level=False)

# %%
temp_rsq = wide_rsq_df.dropna()[("batch_1","h9")]
temp_rsq

fig, ax = plt.subplots(1,1, figsize=(4,4))

for threshold in [0.9,0.8,0.7,0.6,0.5]:
    selected_pos = temp_rsq.loc[temp_rsq>=threshold].index
    selected_pos = bulk2single_reac_single.index.intersection(bulk2single_reac_bulk.index).intersection(selected_pos)
    
    local_single = bulk2single_reac_single.loc[selected_pos].sort_index()
    local_bulk = bulk2single_reac_bulk.loc[selected_pos].sort_index()
    
    print (selected_pos.size)
    
    sns.kdeplot(local_single.corrwith(local_bulk.mean(axis=1), method="spearman"), ax=ax, 
                label="{}, N={}".format(threshold, selected_pos.size), common_norm=False)
ax.set_xlim(0.0,0.6)
plt.legend(fontsize=8)
plt.savefig("../Current_Figures/02. rRNA_reactivity_correlation/Correlation_bulk2single.reac.mosthomogeneous.nts.common_region_across_stages.pdf")
plt.show()
# Out:
# 1438
# 2231
# 3461
# 5158
# 7418

# %%
bulk2single_mutrate = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/batch_1.h9.bulk2single.mutrate.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
bulk2single_mutrate_rRNA = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/batch_1.h9.bulk2single.mutrate.1nt.rRNA.csv", header=[0,1,2,3,4], index_col=[0,1])

bulk2single_mutrate = bulk2single_mutrate.loc[bulk2single_mutrate.index.get_level_values('gene')!="human_small"]
bulk2single_mutrate = pd.concat([bulk2single_mutrate, bulk2single_mutrate_rRNA])
bulk2single_mutrate = bulk2single_mutrate.xs('batch_1', level="batch", axis=1)

bulk2single_mutrate_dmso = bulk2single_mutrate.xs('dmso', level="agent", axis=1, drop_level=False)
bulk2single_mutrate_nai = bulk2single_mutrate.xs('nai-n3', level="agent", axis=1, drop_level=False)
bulk2single_mutrate_dmso_single = bulk2single_mutrate_dmso.xs('single', level="lib_type", axis=1, drop_level=False)
bulk2single_mutrate_nai_single = bulk2single_mutrate_nai.xs('single', level="lib_type", axis=1, drop_level=False)

bulk2single_mutrate_dmso_bulk = bulk2single_mutrate_dmso.xs('bulk', level="lib_type", axis=1, drop_level=False)
bulk2single_mutrate_nai_bulk = bulk2single_mutrate_nai.xs('bulk', level="lib_type", axis=1, drop_level=False)
bulk2single_mutrate_dmso_bulk = bulk2single_mutrate_dmso_bulk.loc[bulk2single_mutrate_dmso_bulk.max(axis=1)<0.1]
bulk2single_mutrate_nai_bulk = bulk2single_mutrate_nai_bulk.loc[bulk2single_mutrate_dmso_bulk.index]

# %%
temp_rsq = wide_rsq_df[("batch_1","h9")]
temp_rsq
fig, ax = plt.subplots(1,1, figsize=(8,3))

for threshold in [0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]:
    selected_pos = temp_rsq.loc[temp_rsq>=threshold].index
    selected_pos = bulk2single_mutrate_nai_single.index.intersection(bulk2single_mutrate_nai_bulk.index).intersection(selected_pos)
    
    local_single = bulk2single_mutrate_nai_single.loc[selected_pos].sort_index()
    local_bulk = bulk2single_mutrate_nai_bulk.loc[selected_pos].sort_index()
    
    print (selected_pos.size)
    
    
    sns.kdeplot(local_single.corrwith(local_bulk.mean(axis=1)), ax=ax, 
                label="{}, N={}".format(threshold, selected_pos.size), common_norm=False)
ax.set_xlim(0.2,1.1)
plt.legend(fontsize=8, loc="upper right")
plt.savefig("../Current_Figures/02. rRNA_reactivity_correlation/Correlation_bulk2single.mutrate.mosthomogeneous.nts.more_threshold.pdf")
plt.show()
# Out:
# 2959
# 15096
# 41523
# 80709
# 129492
# 186419
# 249972
# 320516
# 404403

# %%
temp_rsq = wide_rsq_df[("batch_1","h9")]
temp_rsq
fig, ax = plt.subplots(1,1, figsize=(8,3))

for threshold in [0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]:
    selected_pos = temp_rsq.loc[temp_rsq>=threshold].index
    selected_pos = bulk2single_mutrate_nai_single.index.intersection(bulk2single_mutrate_nai_bulk.index).intersection(selected_pos)
    
    local_single = bulk2single_mutrate_nai_single.loc[selected_pos].sort_index()
    local_bulk = bulk2single_mutrate_nai_bulk.loc[selected_pos].sort_index()
    
    local_corr = pd.DataFrame(np.triu(local_single.corr()), index=local_single.columns, columns=local_single.columns)
    local_corr = local_corr.replace(0, np.nan)
    local_corr = local_corr.replace(1, np.nan)
    local_corr = local_corr.stack([0,1,2,3]).to_frame('corr')
    
    #print (local_corr)
    
    
    sns.kdeplot( local_corr['corr'], ax=ax, 
                label="{}, N={}".format(threshold, selected_pos.size), common_norm=False)
    ax.set_xlim(0.05,1.1)
plt.legend(fontsize=8, loc="upper right")
plt.savefig("../Current_Figures/02. rRNA_reactivity_correlation/Correlation_single2single.mutrate.mosthomogeneous.nts.more_threshold.pdf")
plt.show()

# %%
temp_rsq = wide_rsq_df[("batch_1","h9")]
temp_rsq

    
fig, ax = plt.subplots(1,1, figsize=(8,3))

for threshold in [0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]:
    selected_pos = temp_rsq.loc[temp_rsq>=threshold].index
    selected_pos = bulk2single_mutrate_dmso_single.index.intersection(bulk2single_mutrate_dmso_bulk.index).intersection(selected_pos)
    
    local_single = bulk2single_mutrate_dmso_single.loc[selected_pos].sort_index()
    local_bulk = bulk2single_mutrate_dmso_bulk.loc[selected_pos].sort_index()
        
    sns.kdeplot(local_single.corrwith(local_bulk.mean(axis=1)), ax=ax,  
                label="{}, N={}".format(threshold, selected_pos.size), common_norm=False)
ax.set_xlim(0.2,1.1)
plt.legend(fontsize=8)
plt.savefig("../Current_Figures/02. rRNA_reactivity_correlation/Correlation_bulk2single.mutrate.dmso.mosthomogeneous.nts.more_threshold.pdf")
plt.show()

# %%
gene_h9_crude_reac_stacked = gene_h9_crude_reac.stack([0,1]).to_frame('reac').reset_index()
gene_h9_crude_reac_stacked
# Out:
#        pos       id lib_type      reac
# 0     1835  RHE1552   single -0.005966
# 1     1835  RHE1577   single -0.005966
# 2     1835  RHE1578   single -0.003188
# 3     1835  RHE1581   single  0.000344
# 4     1835  RHE1582   single  0.069877
# ...    ...      ...      ...       ...
# 7665  2132  RHE1614   single -0.003868
# 7666  2132  RHE1615   single  0.003431
# 7667  2132  RHE1653   single  0.008327
# 7668  2132  RHE1654   single -0.001113
# 7669  2132  RHE1655   single -0.002679
#
# [7670 rows x 4 columns]

# %% [markdown]
# ## 2. Plot heatmap of single genes

# %%
common_genes = load_large_dataFrame("../Current_Data/05.Gene_Heterogeneity/common gene btw_htg_from_crude_reac_and_qnorm_reac.csv")
common_genes
# Out:
# Index(['PRDX4', 'FIBP', 'VCP', 'POLR3K', 'PGK1', 'CCT3', 'ECHS1', 'STIP1',
#        'PHB2', 'PCBP1',
#        ...
#        'ARPC3', 'MAP1B', 'PFN2', 'HNRNPR', 'SEPTIN7', 'CAPZA1', 'ATP5PB',
#        'EIF3A', 'YWHAQ', 'SRP9'],
#       dtype='object', name='common_genes', length=115)

# %%
gene = "RPS27"

#for gene in ['RPS27', 'RPL13A', 'FKBP4']:


#
#for gene in ['RPS29','RPL37A','RPL13A','RPL30','ATP5F1E','RPL5']:
#for gene in ['RPS29','RPL13A','RPS15A','RPL13A','ATP5F1E','MZT2A']:
#for gene in ['MTCH2','SLC25A5','ATP6V1G1','UCHL1','CD63']:
#or gene in common_genes.index:
#for gene in ['AHCY','EIF5','ARPC2','SKP1','ATP6V1G1','S100A10','COPS6','MTCH2']:
for gene in ['RPS27']:
    
    #gene_h9_crude_reac = h9_crude_reac_10nt.loc[gene]
    if gene not in h9_crude_reac.index.get_level_values('gene'):
        continue
    #gene_h9_crude_reac = h9_crude_reac.loc[gene]
    gene_h9_crude_reac = h9_gnorm_reac.loc[gene]

    
    gene_h9_crude_reac = gene_h9_crude_reac.dropna(how="any", thresh=0.8*gene_h9_crude_reac.index.size,  axis=1)
    gene_h9_crude_reac = gene_h9_crude_reac.dropna()
    #gene_h9_crude_reac = gene_h9_crude_reac.xs('batch_1', level='batch', axis=1)
    
    if  (gene_h9_crude_reac.index.size < 300) | (gene_h9_crude_reac.columns.size < 20):
        continue
    
    # h = sns.clustermap(gene_h9_crude_reac, vmin=-0.25, vmax=2, cmap="viridis", row_cluster=False, col_cluster=True, figsize=(3,5))
    # plt.savefig("../Current_Figures/06.Heterogeneity_Distribution/reac2rsq.{}.crude_reac.clusted.heatmap.viridis.pdf".format(gene))
    # plt.show()
    dgram = h.dendrogram_col.dendrogram
    gene_h9_crude_reac.iloc[:,dgram['leaves']]
    #dgram.keys()

    gene_rsq_df = wide_rsq_df.loc[gene].xs('h9', level="stage", axis=1).reset_index()
    #gene_rsq_df = wide_rsq_df_10nt.loc[gene][['h9']]
    #gene_rsq_df.columns = ['batch_1']
    gene_rsq_df = gene_rsq_df.reset_index()
    gene_rsq_df = gene_rsq_df.loc[gene_rsq_df['pos'].isin(gene_h9_crude_reac.index.get_level_values('pos'))]
    
    gene_h9_crude_reac_stacked = gene_h9_crude_reac.stack(list(range(gene_h9_crude_reac.columns.nlevels))).to_frame('reac').reset_index()
    gene_h9_crude_reac_stacked
    

    fig = plt.figure(constrained_layout=False, figsize=(8,7))
    gridspec = fig.add_gridspec(nrows=60, ncols=90, left=0.1, right=0.9, bottom=0.2, top=0.9, wspace=0.1, hspace=0.1)
    heatmap_cbar_ax = fig.add_subplot(gridspec[12:24, 7:9])
    reac_heatmap_ax = fig.add_subplot(gridspec[12:52, 10:40])
    rsq_curve_ax = fig.add_subplot(gridspec[12:52, 42:60])
    reac_curve_ax = fig.add_subplot(gridspec[12:52, 65:83])
    #sns.heatmap(gene_h9_crude_reac.iloc[:,dgram['leaves']].sort_index(), vmin=0, vmax=0.06, cmap="viridis", ax=reac_heatmap_ax, cbar_ax=heatmap_cbar_ax,  #viridis
    #            xticklabels=False, yticklabels=False)
    sns.heatmap(gene_h9_crude_reac.iloc[:,dgram['leaves']].sort_index(), vmin=0, vmax=3, cmap="viridis", ax=reac_heatmap_ax, cbar_ax=heatmap_cbar_ax,  #viridis
                xticklabels=False, yticklabels=False)
    reac_heatmap_ax.set_title(gene)
    #sns.lineplot(data=gene_rsq_df, x="pos", y="batch_1", ax=rsq_curve_ax, orientation='vertica')
    rsq_curve_ax.plot(gene_rsq_df["batch_1"], gene_rsq_df['pos'], lw=0.3, color="black")
    heatmap_cbar_ax.yaxis.tick_left()

    #eac_curve_ax.plot(gene_h9_crude_reac_stacked['reac'],gene_h9_crude_reac_stacked['pos'], lw=0.3, color="black")
    sns.lineplot(data=gene_h9_crude_reac_stacked, x='reac', y="pos", orient="y", ax=reac_curve_ax, color="black",  lw=0.3)
    reac_curve_ax.set_xlim(-0.2, 4)
    reac_curve_ax.set_ylim(gene_h9_crude_reac.index.get_level_values('pos').min(), gene_h9_crude_reac.index.get_level_values('pos').max())
    reac_curve_ax.invert_yaxis()
    reac_curve_ax.yaxis.tick_right()
    reac_curve_ax.set_xlabel('Raw Reactivity', loc="center")
    reac_curve_ax.xaxis.tick_top()
    reac_curve_ax.xaxis.set_label_position('top')
    
    rsq_curve_ax.set_ylim(gene_h9_crude_reac.index.get_level_values('pos').min(), gene_h9_crude_reac.index.get_level_values('pos').max())
    rsq_curve_ax.invert_yaxis()
    rsq_curve_ax.yaxis.tick_right()
    rsq_curve_ax.set_xlabel('Heterogeneity (Rsq)', loc="center")
    rsq_curve_ax.set_xlim(-0.02,1.1)
    rsq_curve_ax.xaxis.tick_top()
    rsq_curve_ax.xaxis.set_label_position('top')
    rsq_curve_ax.axvline(x=0.5, lw=0.5, ls='--')
    plt.tight_layout()
    
    #plt.savefig("../Current_Figures/06.Heterogeneity_Distribution/reac2rsq.{}.crude_reac.heatmap.viridis.pdf".format(gene))
    plt.show()

# %%
for gene in ['RPS27']:
    
    #gene_h9_crude_reac = h9_crude_reac_10nt.loc[gene]
    if gene not in h9_crude_reac.index.get_level_values('gene'):
        continue
    #gene_h9_crude_reac = h9_crude_reac.loc[gene]
    gene_h9_crude_reac = h9_gnorm_reac.loc[gene]
    bulk_gene_reac = bulk_reac.loc[gene]
    gene_h9_crude_reac = gene_h9_crude_reac.loc[gene_h9_crude_reac.index.intersection(bulk_gene_reac.index)].sort_index()
    bulk_gene_reac = bulk_gene_reac.loc[gene_h9_crude_reac.index.intersection(bulk_gene_reac.index)].sort_index()
    t = pd.CategoricalDtype(categories=['cell_10','cell_100','bulk'], ordered=True)
    bulk_gene_reac.columns = bulk_gene_reac.columns.astype(t)
    bulk_gene_reac.sort_index(axis=1, inplace=True)
    #bulk_gene_reac = bulk_gene_reac.loc[:, ()]
    #print (gene_h9_crude_reac)
    #print (bulk_gene_reac)
    
    gene_h9_crude_reac = gene_h9_crude_reac.dropna(how="any", thresh=0.8*gene_h9_crude_reac.index.size,  axis=1)
    gene_h9_crude_reac = gene_h9_crude_reac.dropna()
    
    
    gene_h9_crude_reac = gene_h9_crude_reac.xs('batch_1', level='batch', axis=1)
    
    if  (gene_h9_crude_reac.index.size < 100) | (gene_h9_crude_reac.columns.size < 20):
        continue
    
    # h = sns.clustermap(gene_h9_crude_reac, vmin=-0.25, vmax=2, cmap="viridis", row_cluster=False, col_cluster=True, figsize=(3,5))
    # plt.savefig("../Current_Figures/06.Heterogeneity_Distribution/reac2rsq.{}.crude_reac.clusted.heatmap.viridis.pdf".format(gene))
    # plt.show()
    #dgram = h.dendrogram_col.dendrogram
    #gene_h9_crude_reac.iloc[:,dgram['leaves']]
    
    col_order = gene_h9_crude_reac.sort_index(axis=1).columns.to_list()
    random.shuffle(col_order)
    gene_h9_crude_reac = gene_h9_crude_reac.loc[:,  col_order]
    #dgram.keys()

    
    gene_h9_crude_reac_stacked = gene_h9_crude_reac.stack(list(range(gene_h9_crude_reac.columns.nlevels))).to_frame('reac').reset_index()
    gene_h9_crude_reac_stacked
    

    fig = plt.figure(constrained_layout=False, figsize=(6,8))
    gridspec = fig.add_gridspec(nrows=60, ncols=80, left=0.1, right=0.9, bottom=0.2, top=0.9, wspace=0.1, hspace=0.1)
    heatmap_cbar_ax = fig.add_subplot(gridspec[12:24, 7:9])
    reac_heatmap_ax = fig.add_subplot(gridspec[12:52, 15:45])
    
    
    bulk_heatmap_ax = fig.add_subplot(gridspec[12:52, 50:65])
    #reac_curve_ax = fig.add_subplot(gridspec[12:52, 65:83])
    #sns.heatmap(gene_h9_crude_reac.iloc[:,dgram['leaves']].sort_index(), vmin=0, vmax=0.06, cmap="viridis", ax=reac_heatmap_ax, cbar_ax=heatmap_cbar_ax,  #viridis
    #            xticklabels=False, yticklabels=False)
    sns.heatmap(gene_h9_crude_reac, vmin=0, vmax=3, cmap="viridis", ax=reac_heatmap_ax, cbar_ax=heatmap_cbar_ax,  #viridis
                xticklabels=False)
    sns.heatmap(bulk_gene_reac, vmin=0, vmax=3, cmap="viridis", ax=bulk_heatmap_ax, cbar=False,  #viridis
                xticklabels=True, yticklabels=False)
    reac_heatmap_ax.set_title(gene)
    #sns.lineplot(data=gene_rsq_df, x="pos", y="batch_1", ax=rsq_curve_ax, orientation='vertica')
    #rsq_curve_ax.plot(gene_rsq_df["batch_1"], gene_rsq_df['pos'], lw=0.3, color="black")
    heatmap_cbar_ax.yaxis.tick_left()
    for label in bulk_heatmap_ax.get_yticklabels():
        label.set_rotation(270)
    #plt.tight_layout()
    
    plt.savefig("../Current_Figures/06.Heterogeneity_Distribution/reac2rsq.{}.gnorm_reac.single2bulk.heatmap.viridis.pdf".format(gene))
    plt.show()

# %%
print ([random.shuffle()])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 print ([random.shuffle()])
#
# TypeError: shuffle() missing 1 required positional argument: 'x'

# %% [markdown]
# ### 2.1

# %%
for gene in ['MTCH2','SLC25A5','ATP6V1G1','UCHL1','CD63']:
    #gene_h9_crude_reac = h9_crude_reac_10nt.loc[gene]
    gene_h9_crude_reac = h9_mutrate.loc[gene]
    #gene_h9_crude_reac = h9_gnorm_reac.loc[gene]
    
    gene_h9_crude_reac = gene_h9_crude_reac.dropna(how="any", thresh=0.8*gene_h9_crude_reac.index.size,  axis=1)
    gene_h9_crude_reac = gene_h9_crude_reac.iloc[10:-10]
    gene_h9_crude_reac = gene_h9_crude_reac.xs('batch_1', level='batch', axis=1)
    #gene_h9_crude_reac = gene_h9_crude_reac.dropna()
    
    h = sns.clustermap(gene_h9_crude_reac.dropna(), cmap="coolwarm", row_cluster=False, col_cluster=True, vmin=-0.02, vmax=0.15, figsize=(3,6))
    plt.show()
    dgram = h.dendrogram_col.dendrogram
    gene_h9_crude_reac.iloc[:,dgram['leaves']]
    #dgram.keys()

    gene_rsq_df = wide_rsq_df.loc[gene].xs('h9', level="stage", axis=1).reset_index()
    #gene_rsq_df = wide_rsq_df_10nt.loc[gene][['h9']]
    #gene_rsq_df.columns = ['batch_1']
    gene_rsq_df = gene_rsq_df.reset_index()
    gene_rsq_df = gene_rsq_df.loc[gene_rsq_df['pos'].isin(gene_h9_crude_reac.index.get_level_values('pos'))]
    
    gene_h9_crude_reac_stacked = gene_h9_crude_reac.stack(list(range(gene_h9_crude_reac.columns.nlevels))).to_frame('reac').reset_index()
    gene_h9_crude_reac_stacked
    

    fig = plt.figure(constrained_layout=False, figsize=(8,7))
    gridspec = fig.add_gridspec(nrows=60, ncols=90, left=0.1, right=0.9, bottom=0.2, top=0.9, wspace=0.1, hspace=0.1)
    heatmap_cbar_ax = fig.add_subplot(gridspec[12:24, 7:9])
    reac_heatmap_ax = fig.add_subplot(gridspec[12:52, 10:40])
    rsq_curve_ax = fig.add_subplot(gridspec[12:52, 42:60])
    reac_curve_ax = fig.add_subplot(gridspec[12:52, 65:83])
    sns.heatmap(gene_h9_crude_reac.iloc[:,dgram['leaves']].sort_index().fillna(0), vmin=0, vmax=0.1, cmap="viridis", ax=reac_heatmap_ax, cbar_ax=heatmap_cbar_ax,  #viridis
                xticklabels=False, yticklabels=False)
    reac_heatmap_ax.set_title(gene)
    #sns.lineplot(data=gene_rsq_df, x="pos", y="batch_1", ax=rsq_curve_ax, orientation='vertica')
    #rsq_curve_ax.plot(gene_rsq_df["batch_1"], gene_rsq_df['pos'], lw=0.3, color="black")
    sns.lineplot(data=gene_rsq_df, x='batch_1', y="pos", orient="y", ax=rsq_curve_ax, color="black", lw=0.3)
    heatmap_cbar_ax.yaxis.tick_left()

    #reac_curve_ax.plot(gene_h9_crude_reac_stacked['reac'],gene_h9_crude_reac_stacked['pos'], lw=0.3, color="black")
    sns.lineplot(data=gene_h9_crude_reac_stacked, x='reac', y="pos", orient="y", ax=reac_curve_ax, color="black",  lw=0.3)
    reac_curve_ax.set_xlim(-0.01, 0.25)
    reac_curve_ax.set_ylim(gene_h9_crude_reac.index.get_level_values('pos').min(), gene_h9_crude_reac.index.get_level_values('pos').max())
    reac_curve_ax.invert_yaxis()
    reac_curve_ax.yaxis.tick_right()
    reac_curve_ax.set_xlabel('Raw Mutrate', loc="center")
    reac_curve_ax.xaxis.tick_top()
    reac_curve_ax.xaxis.set_label_position('top')
    
    rsq_curve_ax.set_ylim(gene_h9_crude_reac.index.get_level_values('pos').min(), gene_h9_crude_reac.index.get_level_values('pos').max())
    rsq_curve_ax.invert_yaxis()
    rsq_curve_ax.yaxis.tick_right()
    rsq_curve_ax.set_xlabel('Heterogeneity (Rsq)', loc="center")
    rsq_curve_ax.set_xlim(0,1.1)
    rsq_curve_ax.xaxis.tick_top()
    rsq_curve_ax.xaxis.set_label_position('top')
    rsq_curve_ax.axvline(x=0.5, lw=0.5, ls='--')
    plt.tight_layout()
    
    #plt.savefig("../Current_Figures/06.Heterogeneity_Distribution/reac2rsq.{}.mutrate.heatmap.viridis.pdf".format(gene))
    plt.show()

# %% [markdown]
# ## 3. Density Plot of Rsq in single gene

# %%
gene = "RPL13A"

fig, ax = plt.subplots(1,1)
#for gene in ['RPS27', 'RPL13A', 'FKBP4']:

#for gene in hetero_genes:

concat_lst  = []
#for gene in ['RPL13A','RPS29','RPL37','RPL39','RPL26','RPS24']:  ## ,'RPS29','RPS15A', 'SKP1','DDX5',
#for gene in ['RPL13A','RPL37A','ATP5F1E','RPL5']:  ## ,'RPS29','RPS15A', 'SKP1','DDX5', 'RPS29','RPS29',
for gene1 in ['MTCH2','SLC25A5','RPL8','ATP6V1G1','RBX1','UCHL1','CD63','RPS15A','MZT2A']:

   
    for gene in ['RPL13A',gene1]:  ## ,'RPS29','RPS15A', 'SKP1','DDX5', 'RPS29','RPS29',
    
        print (gene)
        #gene_h9_crude_reac = h9_crude_reac_10nt.loc[gene]
        gene_h9_crude_reac = h9_crude_reac.loc[gene]
        #gene_h9_crude_reac = h9_gnorm_reac.loc[gene]

        gene_h9_crude_reac = gene_h9_crude_reac.dropna(how="any", thresh=0.8*gene_h9_crude_reac.index.size,  axis=1)
        gene_h9_crude_reac = gene_h9_crude_reac.dropna()
        gene_h9_crude_reac = gene_h9_crude_reac.xs('batch_1', level='batch', axis=1)


        #h = sns.clustermap(gene_h9_crude_reac, cmap="coolwarm", row_cluster=False, col_cluster=True, vmin=-0.02, vmax=0.05, figsize=(3,6))
        #plt.show()
        #dgram = h.dendrogram_col.dendrogram
        #gene_h9_crude_reac.iloc[:,dgram['leaves']]
        #dgram.keys()

        gene_rsq_df = wide_rsq_df.loc[gene].xs('h9', level="stage", axis=1).reset_index()
        #gene_rsq_df = wide_rsq_df_10nt.loc[gene][['h9']]
        #gene_rsq_df.columns = ['batch_1']
        gene_rsq_df = gene_rsq_df.reset_index()
        gene_rsq_df = gene_rsq_df.loc[gene_rsq_df['pos'].isin(gene_h9_crude_reac.index.get_level_values('pos'))]

        #print (gene_rsq_df)
        #sns.histplot(data=gene_rsq_df, x="batch_1", label=gene, stat='probability')
        sns.kdeplot(data=gene_rsq_df, x="batch_1", label=gene, common_norm=False, bw_method=0.2) #, bw_adjust=0.5
        gene_rsq_df['gene'] = gene
        concat_lst.append(gene_rsq_df)
    plt.legend()
    #plt.savefig("../Current_Figures/06.Heterogeneity_Distribution/reac2rsq.rsq_density_for_each_gene.kdeplot.pdf")
    plt.show()


    gene_rsq_df = pd.concat(concat_lst)
    gene_rsq_df.rename(columns={'batch_1':'rsq'}, inplace=True)
    fig, axs = plt.subplots(2,1, figsize=(4,6))
    sns.violinplot(data=gene_rsq_df, x='gene', y="rsq", ax=axs[0])
    sns.boxplot(data=gene_rsq_df, x='gene', y="rsq", ax=axs[1])
    #plt.savefig("../Current_Figures/06.Heterogeneity_Distribution/reac2rsq.rsq_density_for_each_gene.boxplot.pdf")
    plt.show()
# Out:
# RPL13A
# MTCH2
# RPL13A
# SLC25A5
# RPL13A
# RPL8
# RPL13A
# ATP6V1G1
# RPL13A
# RBX1
# RPL13A
# UCHL1
# RPL13A
# CD63
# RPL13A
# RPS15A
# RPL13A
# MZT2A

# %%
#gene_rsq_df

# %%
gene = "RPL13A"

fig, ax = plt.subplots(1,1)
#for gene in ['RPS27', 'RPL13A', 'FKBP4']:

#for gene in hetero_genes:

concat_lst  = []
#for gene in ['RPL13A','RPS29','RPL37','RPL39','RPL26','RPS24']:  ## ,'RPS29','RPS15A', 'SKP1','DDX5',
for gene in ['RPS29','RPL13A','RPL37A','RPL26','RPL30','TUBB2B','RPS8','TMSB10','RPL39','RPS25','ATP5F1E','RPL8','RPL4','RPL5']:  ## ,'RPS29','RPS15A', 'SKP1','DDX5', 'RPS29',
    
    print (gene)
    #gene_h9_crude_reac = h9_crude_reac_10nt.loc[gene]
    gene_h9_crude_reac = h9_crude_reac.loc[gene]
    #gene_h9_crude_reac = h9_gnorm_reac.loc[gene]
    
    gene_h9_crude_reac = gene_h9_crude_reac.dropna(how="any", thresh=0.8*gene_h9_crude_reac.index.size,  axis=1)
    gene_h9_crude_reac = gene_h9_crude_reac.dropna()
    gene_h9_crude_reac = gene_h9_crude_reac.xs('batch_1', level='batch', axis=1)
    
    
    #h = sns.clustermap(gene_h9_crude_reac, cmap="coolwarm", row_cluster=False, col_cluster=True, vmin=-0.02, vmax=0.05, figsize=(3,6))
    #plt.show()
    #dgram = h.dendrogram_col.dendrogram
    #gene_h9_crude_reac.iloc[:,dgram['leaves']]
    #dgram.keys()

    gene_rsq_df = wide_rsq_df.loc[gene].xs('h9', level="stage", axis=1).reset_index()
    #gene_rsq_df = wide_rsq_df_10nt.loc[gene][['h9']]
    #gene_rsq_df.columns = ['batch_1']
    gene_rsq_df = gene_rsq_df.reset_index()
    gene_rsq_df = gene_rsq_df.loc[gene_rsq_df['pos'].isin(gene_h9_crude_reac.index.get_level_values('pos'))]
    
    #print (gene_rsq_df)
    #sns.histplot(data=gene_rsq_df, x="batch_1", label=gene, stat='probability')
    sns.kdeplot(data=gene_rsq_df, x="batch_1", label=gene, common_norm=False, bw_method=0.2) #, bw_adjust=0.5
    gene_rsq_df['gene'] = gene
    concat_lst.append(gene_rsq_df)
plt.legend()
plt.show()
# Out:
# RPS29
# RPL13A
# RPL37A
# RPL26
# RPL30
# TUBB2B
# RPS8
# TMSB10
# RPL39
# RPS25
# ATP5F1E
# RPL8
# RPL4
# RPL5

# %%
gene_rsq_df = pd.concat(concat_lst)
fig, axs = plt.subplots(2,1, figsize=(12,6))
sns.violinplot(data=gene_rsq_df, x='gene', y="batch_1", ax=axs[0])
sns.boxplot(data=gene_rsq_df, x='gene', y="batch_1", ax=axs[1])
plt.show()
#gene_rsq_df

# %% [markdown]
# ## 4. recalculate the Rsq to remove teniqual replicates

# %%
## Retrieve mutant matrix
b1_h9_mutant = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.h9.mutant.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_h9_mutant = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.h9.mutant.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b1_day0_mutant = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.day0.mutant.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_day0_mutant = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.day0.mutant.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b1_day1_mutant = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.day1.mutant.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_day1_mutant = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.day1.mutant.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b1_day7_mutant = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.day7.mutant.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_day7_mutant = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.day7.mutant.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])

h9_mutant = pd.concat([b1_h9_mutant, b2_h9_mutant], axis=1)
day0_mutant = pd.concat([b1_day0_mutant, b2_day0_mutant], axis=1)
day1_mutant = pd.concat([b1_day1_mutant, b2_day1_mutant], axis=1)
day7_mutant = pd.concat([b1_day7_mutant, b2_day7_mutant], axis=1)

h9_mutant = h9_mutant.loc[h9_mutant.isnull().sum(axis=1) < h9_mutant.columns.size*0.5]
day0_mutant = day0_mutant.loc[day0_mutant.isnull().sum(axis=1) < day0_mutant.columns.size*0.5]
day1_mutant = day1_mutant.loc[day1_mutant.isnull().sum(axis=1) < day1_mutant.columns.size*0.5]
day7_mutant = day7_mutant.loc[day7_mutant.isnull().sum(axis=1) < day7_mutant.columns.size*0.5]

### add rRNAs
rRNA_df = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/all_cells.mutant.rRNA.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
def add_rRNA_data(rRNA_df, df):
    df = df.loc[~df.index.get_level_values('gene').isin(['human_small', 'human_large'])]
    df = pd.concat([df, rRNA_df], join="inner")
    return df
h9_mutant = add_rRNA_data(rRNA_df, h9_mutant)
day0_mutant = add_rRNA_data(rRNA_df, day0_mutant)
day1_mutant = add_rRNA_data(rRNA_df, day1_mutant)
day7_mutant = add_rRNA_data(rRNA_df, day7_mutant)

mutant_df = pd.concat([h9_mutant, day0_mutant, day1_mutant, day7_mutant], axis=1)
#mutant_df

# %%
## Retrieve coverage matrix
b1_h9_coverage = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.h9.coverage.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_h9_coverage = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.h9.coverage.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b1_day0_coverage = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.day0.coverage.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_day0_coverage = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.day0.coverage.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b1_day1_coverage = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.day1.coverage.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_day1_coverage = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.day1.coverage.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b1_day7_coverage = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_1.day7.coverage.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
b2_day7_coverage = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/batch_2.day7.coverage.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])

h9_coverage = pd.concat([b1_h9_coverage, b2_h9_coverage], axis=1)
day0_coverage = pd.concat([b1_day0_coverage, b2_day0_coverage], axis=1)
day1_coverage = pd.concat([b1_day1_coverage, b2_day1_coverage], axis=1)
day7_coverage = pd.concat([b1_day7_coverage, b2_day7_coverage], axis=1)

h9_coverage = h9_coverage.loc[h9_coverage.isnull().sum(axis=1) < h9_coverage.columns.size*0.5]
day0_coverage = day0_coverage.loc[day0_coverage.isnull().sum(axis=1) < day0_coverage.columns.size*0.5]
day1_coverage = day1_coverage.loc[day1_coverage.isnull().sum(axis=1) < day1_coverage.columns.size*0.5]
day7_coverage = day7_coverage.loc[day7_coverage.isnull().sum(axis=1) < day7_coverage.columns.size*0.5]

### add rRNAs
rRNA_df = load_large_dataFrame("../Current_Data/02.Mutant_Rate_Matrix.1nt/neural_differentiation.mutrate_data/all_cells.coverage.rRNA.1nt.csv", header=[0,1,2,3,4], index_col=[0,1])
def add_rRNA_data(rRNA_df, df):
    df = df.loc[~df.index.get_level_values('gene').isin(['human_small', 'human_large'])]
    df = pd.concat([df, rRNA_df], join="inner")
    return df
h9_coverage = add_rRNA_data(rRNA_df, h9_coverage)
day0_coverage = add_rRNA_data(rRNA_df, day0_coverage)
day1_coverage = add_rRNA_data(rRNA_df, day1_coverage)
day7_coverage = add_rRNA_data(rRNA_df, day7_coverage)

coverage_df = pd.concat([h9_coverage, day0_coverage, day1_coverage, day7_coverage], axis=1)
#coverage_df

# %%
mutant_df.loc[:, ~mutant_df.columns.get_level_values('id').isin(['RHE1585', 'RHE1614','RHE1587','RHE1615','RHE1600','RHE1653','RHE1602','RHE1655','RHE1584'])]
coverage_df.loc[:, ~coverage_df.columns.get_level_values('id').isin(['RHE1585', 'RHE1614','RHE1587','RHE1615','RHE1600','RHE1653','RHE1602','RHE1655','RHE1584'])]

genes = ['RPS27', 'RPL13A', 'FKBP4']
mutant_df = mutant_df.loc[mutant_df.index.get_level_values('gene').isin(genes)]
coverage_df = coverage_df.loc[coverage_df.index.get_level_values('gene').isin(genes)]

# %%
def calculate_Rsq_of_coverage_to_mutant(mutant_df, coverage_df):
    mutant_df = mutant_df.dropna(how="all")
    coverage_df = coverage_df.dropna(how="all")
    intersect_index = mutant_df.index.intersection(coverage_df.index)
    concat_list = []
    for idx in intersect_index:
        mutant_series = mutant_df.loc[idx]
        coverage_series = coverage_df.loc[idx]
        mutant_series = mutant_series.dropna()
        coverage_series = coverage_series.dropna()
        intersect_index = mutant_series.index.intersection(coverage_series.index)
        mutant_series = mutant_series.loc[intersect_index]
        coverage_series = coverage_series.loc[intersect_index]
        
        if (mutant_series.size <= 10) or (coverage_series.size <= 10):
            continue
        # print (mutant_series)
        # print (coverage_series)
        try:
            slope, intercept, r, p, stderr = stats.linregress(coverage_series, mutant_series)
        except:
            slope, intercept, r, p, stderr = np.nan, np.nan, np.nan, np.nan, np.nan
        out_series = pd.Series([slope, intercept, r, p, stderr], index=['slope','intercept','r','p','stderr'], name=idx)
        #print (out_series)
        #out_series.name = pd.MultiIndex.from_tuples(idx, names=['gene','pos'])
        concat_list.append(out_series)
    out = pd.concat(concat_list, axis=1)
    out = out.T
    out.index.names = ['gene', 'pos']
    return out

def heterogeneity_by_rsquare(mutant, coverage):
    #dmso_mutant = mutant.xs('dmso', level="agent", axis=1)
    nai_mutant = mutant.xs('nai-n3', level="agent", axis=1)
    #dmso_coverage = coverage.xs('dmso', level="agent", axis=1)
    nai_coverage = coverage.xs('nai-n3', level="agent", axis=1)

    #dmso_rsquare = calculate_Rsq_of_coverage_to_mutant(dmso_mutant, dmso_coverage)
    nai_rsquare = calculate_Rsq_of_coverage_to_mutant(nai_mutant, nai_coverage)
    #return dmso_rsquare, nai_rsquare
    return nai_rsquare

# %%
concat_list = []
for (batch,stage), subset_mutant in mutant_df.groupby(['batch','stage'], axis=1):
    subset_mutant = subset_mutant.dropna(how="all")
    subset_coverage = coverage_df.loc[:, subset_mutant.columns].dropna(how="all")
    intersected_wins = subset_mutant.index.intersection(subset_coverage.index)
    subset_mutant = subset_mutant.loc[intersected_wins]
    subset_coverage = subset_coverage.loc[intersected_wins, subset_mutant.columns]
    subset_rsq_1nts = heterogeneity_by_rsquare(subset_mutant, subset_coverage)
    subset_rsq_1nts['batch']=batch
    subset_rsq_1nts['stage']=stage
    concat_list.append(subset_rsq_1nts)
rsq_1nt = pd.concat(concat_list)
rsq_1nt['rsq'] = np.power(rsq_1nt['r'],2)

# %%
rsq_df = rsq_1nt.copy()
wide_rsq_df = rsq_df.reset_index().pivot(index=['gene','pos'], columns=['batch','stage'], values='rsq')
wide_rsq_df.dropna().index.get_level_values('gene').unique().size
wide_rsq_df
# Out:
# batch        batch_1                                 batch_2            \
# stage           day0      day1      day7        h9      day0      day1
# gene  pos
# FKBP4 1770       NaN       NaN       NaN  0.279562       NaN       NaN
#       1771       NaN       NaN       NaN  0.186580       NaN       NaN
#       1772       NaN       NaN       NaN  0.200973       NaN       NaN
#       1773       NaN       NaN       NaN  0.021632       NaN       NaN
#       1774       NaN       NaN       NaN  0.038019       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# RPS27 340   0.124062  0.102693  0.298974  0.207528  0.031511  0.182165
#       341   0.139217  0.126670  0.545087  0.288195  0.122672  0.100084
#       342   0.058070  0.074326  0.638314  0.309610  0.032921  0.012430
#       343   0.301562  0.024919  0.000479  0.424355  0.094808  0.005790
#       344   0.511220       NaN       NaN  0.804371  0.041391       NaN
#
# batch
# stage           day7        h9
# gene  pos
# FKBP4 1770       NaN  0.817201
#       1771       NaN  0.595814
#       1772       NaN  0.455231
#       1773       NaN  0.006895
#       1774       NaN  0.846659
# ...              ...       ...
# RPS27 340   0.492949  0.197000
#       341   0.017456  0.100176
#       342   0.020475  0.020534
#       343   0.058027  0.194847
#       344        NaN  0.478055
#
# [1422 rows x 8 columns]

# %% [markdown]
# ## 5. propotion of High rsq

# %% [markdown]
# ### 5.1 rsquare

# %%
wide_rsq_df = load_large_dataFrame("../Data/04.heterogeneity_dataframe/rsq.wide_matrix.Mut_vs_Cov.genome.1nt.annot.csv", index_col=[0,1,2,3,4,5,6,7,8], header=[0,1])
wide_rsq_df
# Out:
# batch                                                                                           batch_1  \
# stage                                                                                              day0
# gene        pos  gene_id           biotype full_len cds_start cds_end region     relative_pos
# AARS1       3058 ENST00000565361.3 coding  3572     159       3158    cds        63.166055          NaN
#             3059 ENST00000565361.3 coding  3572     159       3158    cds        63.184395          NaN
#             3060 ENST00000565361.3 coding  3572     159       3158    cds        63.202734          NaN
#             3061 ENST00000565361.3 coding  3572     159       3158    cds        63.221074          NaN
#             3062 ENST00000565361.3 coding  3572     159       3158    cds        63.239413          NaN
# ...                                                                                                 ...
# human_small 1866 human_small       rRNA    1870     1         1870    non_coding NaN           0.515769
#             1867 human_small       rRNA    1870     1         1870    non_coding NaN           0.586221
#             1868 human_small       rRNA    1870     1         1870    non_coding NaN           0.727247
#             1869 human_small       rRNA    1870     1         1870    non_coding NaN           0.743982
#             1870 human_small       rRNA    1870     1         1870    non_coding NaN           0.971789
#
# batch                                                                                                    \
# stage                                                                                              day1
# gene        pos  gene_id           biotype full_len cds_start cds_end region     relative_pos
# AARS1       3058 ENST00000565361.3 coding  3572     159       3158    cds        63.166055          NaN
#             3059 ENST00000565361.3 coding  3572     159       3158    cds        63.184395          NaN
#             3060 ENST00000565361.3 coding  3572     159       3158    cds        63.202734          NaN
#             3061 ENST00000565361.3 coding  3572     159       3158    cds        63.221074          NaN
#             3062 ENST00000565361.3 coding  3572     159       3158    cds        63.239413          NaN
# ...                                                                                                 ...
# human_small 1866 human_small       rRNA    1870     1         1870    non_coding NaN           0.700049
#             1867 human_small       rRNA    1870     1         1870    non_coding NaN           0.617221
#             1868 human_small       rRNA    1870     1         1870    non_coding NaN           0.803772
#             1869 human_small       rRNA    1870     1         1870    non_coding NaN           0.720285
#             1870 human_small       rRNA    1870     1         1870    non_coding NaN           0.995001
#
# batch                                                                                                    \
# stage                                                                                              day7
# gene        pos  gene_id           biotype full_len cds_start cds_end region     relative_pos
# AARS1       3058 ENST00000565361.3 coding  3572     159       3158    cds        63.166055          NaN
#             3059 ENST00000565361.3 coding  3572     159       3158    cds        63.184395          NaN
#             3060 ENST00000565361.3 coding  3572     159       3158    cds        63.202734          NaN
#             3061 ENST00000565361.3 coding  3572     159       3158    cds        63.221074          NaN
#             3062 ENST00000565361.3 coding  3572     159       3158    cds        63.239413          NaN
# ...                                                                                                 ...
# human_small 1866 human_small       rRNA    1870     1         1870    non_coding NaN           0.833442
#             1867 human_small       rRNA    1870     1         1870    non_coding NaN           0.741459
#             1868 human_small       rRNA    1870     1         1870    non_coding NaN           0.685847
#             1869 human_small       rRNA    1870     1         1870    non_coding NaN           0.677688
#             1870 human_small       rRNA    1870     1         1870    non_coding NaN           0.979199
#
# batch                                                                                                    \
# stage                                                                                                h9
# gene        pos  gene_id           biotype full_len cds_start cds_end region     relative_pos
# AARS1       3058 ENST00000565361.3 coding  3572     159       3158    cds        63.166055     0.728895
#             3059 ENST00000565361.3 coding  3572     159       3158    cds        63.184395     0.003001
#             3060 ENST00000565361.3 coding  3572     159       3158    cds        63.202734     0.862007
#             3061 ENST00000565361.3 coding  3572     159       3158    cds        63.221074     0.438248
#             3062 ENST00000565361.3 coding  3572     159       3158    cds        63.239413     0.393973
# ...                                                                                                 ...
# human_small 1866 human_small       rRNA    1870     1         1870    non_coding NaN           0.822981
#             1867 human_small       rRNA    1870     1         1870    non_coding NaN           0.966736
#             1868 human_small       rRNA    1870     1         1870    non_coding NaN           0.912938
#             1869 human_small       rRNA    1870     1         1870    non_coding NaN           0.940725
#             1870 human_small       rRNA    1870     1         1870    non_coding NaN           0.996396
#
# batch                                                                                           batch_2  \
# stage                                                                                              day0
# gene        pos  gene_id           biotype full_len cds_start cds_end region     relative_pos
# AARS1       3058 ENST00000565361.3 coding  3572     159       3158    cds        63.166055          NaN
#             3059 ENST00000565361.3 coding  3572     159       3158    cds        63.184395          NaN
#             3060 ENST00000565361.3 coding  3572     159       3158    cds        63.202734          NaN
#             3061 ENST00000565361.3 coding  3572     159       3158    cds        63.221074          NaN
#             3062 ENST00000565361.3 coding  3572     159       3158    cds        63.239413          NaN
# ...                                                                                                 ...
# human_small 1866 human_small       rRNA    1870     1         1870    non_coding NaN           0.356102
#             1867 human_small       rRNA    1870     1         1870    non_coding NaN           0.747014
#             1868 human_small       rRNA    1870     1         1870    non_coding NaN           0.719111
#             1869 human_small       rRNA    1870     1         1870    non_coding NaN           0.693261
#             1870 human_small       rRNA    1870     1         1870    non_coding NaN           0.972004
#
# batch                                                                                                    \
# stage                                                                                              day1
# gene        pos  gene_id           biotype full_len cds_start cds_end region     relative_pos
# AARS1       3058 ENST00000565361.3 coding  3572     159       3158    cds        63.166055          NaN
#             3059 ENST00000565361.3 coding  3572     159       3158    cds        63.184395          NaN
#             3060 ENST00000565361.3 coding  3572     159       3158    cds        63.202734          NaN
#             3061 ENST00000565361.3 coding  3572     159       3158    cds        63.221074          NaN
#             3062 ENST00000565361.3 coding  3572     159       3158    cds        63.239413          NaN
# ...                                                                                                 ...
# human_small 1866 human_small       rRNA    1870     1         1870    non_coding NaN           0.525330
#             1867 human_small       rRNA    1870     1         1870    non_coding NaN           0.512077
#             1868 human_small       rRNA    1870     1         1870    non_coding NaN           0.596047
#             1869 human_small       rRNA    1870     1         1870    non_coding NaN           0.580685
#             1870 human_small       rRNA    1870     1         1870    non_coding NaN           0.960175
#
# batch                                                                                                    \
# stage                                                                                              day7
# gene        pos  gene_id           biotype full_len cds_start cds_end region     relative_pos
# AARS1       3058 ENST00000565361.3 coding  3572     159       3158    cds        63.166055          NaN
#             3059 ENST00000565361.3 coding  3572     159       3158    cds        63.184395          NaN
#             3060 ENST00000565361.3 coding  3572     159       3158    cds        63.202734          NaN
#             3061 ENST00000565361.3 coding  3572     159       3158    cds        63.221074          NaN
#             3062 ENST00000565361.3 coding  3572     159       3158    cds        63.239413          NaN
# ...                                                                                                 ...
# human_small 1866 human_small       rRNA    1870     1         1870    non_coding NaN           0.720521
#             1867 human_small       rRNA    1870     1         1870    non_coding NaN           0.567624
#             1868 human_small       rRNA    1870     1         1870    non_coding NaN           0.594926
#             1869 human_small       rRNA    1870     1         1870    non_coding NaN           0.497781
#             1870 human_small       rRNA    1870     1         1870    non_coding NaN           0.978599
#
# batch
# stage                                                                                                h9
# gene        pos  gene_id           biotype full_len cds_start cds_end region     relative_pos
# AARS1       3058 ENST00000565361.3 coding  3572     159       3158    cds        63.166055     0.546097
#             3059 ENST00000565361.3 coding  3572     159       3158    cds        63.184395     0.003493
#             3060 ENST00000565361.3 coding  3572     159       3158    cds        63.202734     0.047360
#             3061 ENST00000565361.3 coding  3572     159       3158    cds        63.221074     0.190307
#             3062 ENST00000565361.3 coding  3572     159       3158    cds        63.239413     0.693062
# ...                                                                                                 ...
# human_small 1866 human_small       rRNA    1870     1         1870    non_coding NaN           0.797704
#             1867 human_small       rRNA    1870     1         1870    non_coding NaN           0.895338
#             1868 human_small       rRNA    1870     1         1870    non_coding NaN           0.721215
#             1869 human_small       rRNA    1870     1         1870    non_coding NaN           0.734293
#             1870 human_small       rRNA    1870     1         1870    non_coding NaN           0.974076
#
# [597798 rows x 8 columns]

# %% [markdown]
# ### 5.2 heterogeneity by cosine distance

# %%
cosinde_distance_matrix_from_crude_reac = load_large_dataFrame("../Current_Data/05.Gene_Heterogeneity/neural_differentiate.stages.transcripts.crude_reac.cosine_distance_matrix.csv", header=[0,1,2,3])
cosinde_distance_matrix_from_crude_reac

cosinde_distance_matrix_from_scaled_reac = load_large_dataFrame("../Current_Data/05.Gene_Heterogeneity/neural_differentiate.stages.transcripts.scaled_reac.cosine_distance_matrix.csv", header=[0,1,2,3])
cosinde_distance_matrix_from_scaled_reac

cosinde_distance_matrix_from_gnorm_reac = load_large_dataFrame("../Current_Data/05.Gene_Heterogeneity/neural_differentiate.stages.transcripts.gnorm_reac.cosine_distance_matrix.csv", header=[0,1,2,3])
cosinde_distance_matrix_from_gnorm_reac
# Out:
# id            RHE1616   RHE1617   RHE1618   RHE1619   RHE1620   RHE1621  \
# batch         batch_1   batch_1   batch_1   batch_1   batch_1   batch_1
# stage            day0      day0      day0      day0      day0      day0
# lib_type       single    single    single    single    single    single
# AARS1             NaN       NaN       NaN       NaN       NaN       NaN
# AC005329.1        NaN       NaN       NaN       NaN       NaN       NaN
# AC009107.2        NaN       NaN       NaN       NaN       NaN       NaN
# AC009446.1        NaN       NaN       NaN       NaN       NaN       NaN
# AC010624.5        NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# ZNRD2             NaN       NaN       NaN       NaN       NaN       NaN
# ZRANB2            NaN       NaN       NaN       NaN       NaN       NaN
# ZSCAN10           NaN       NaN       NaN       NaN       NaN       NaN
# ZYX               NaN       NaN       NaN       NaN       NaN       NaN
# human_small  0.298561  0.214436  0.306788  0.375248  0.255325  0.143614
#
# id            RHE1622   RHE1623   RHE1624   RHE1625  ...   RHS3587   RHS3588  \
# batch         batch_1   batch_1   batch_1   batch_1  ...   batch_2   batch_2
# stage            day0      day0      day0      day0  ...        h9        h9
# lib_type       single    single    single    single  ...    single    single
# AARS1             NaN       NaN       NaN       NaN  ...  0.663704       NaN
# AC005329.1        NaN       NaN       NaN       NaN  ...  0.591384  0.725664
# AC009107.2        NaN       NaN       NaN       NaN  ...       NaN  0.591417
# AC009446.1        NaN       NaN       NaN       NaN  ...       NaN       NaN
# AC010624.5        NaN       NaN       NaN       NaN  ...  0.706097  0.862357
# ...               ...       ...       ...       ...  ...       ...       ...
# ZNRD2             NaN       NaN       NaN       NaN  ...  0.618142       NaN
# ZRANB2            NaN       NaN       NaN       NaN  ...       NaN       NaN
# ZSCAN10           NaN       NaN       NaN       NaN  ...  0.671509  0.764054
# ZYX               NaN       NaN       NaN       NaN  ...  0.671050  0.618359
# human_small  0.290609  0.229208  0.243603  0.306898  ...  0.140804  0.254183
#
# id            RHS3589   RHS3590   RHS3591   RHS3592   RHS3593   RHS3594  \
# batch         batch_2   batch_2   batch_2   batch_2   batch_2   batch_2
# stage              h9        h9        h9        h9        h9        h9
# lib_type       single    single    single    single    single    single
# AARS1             NaN  0.716860  0.747379       NaN       NaN  0.725874
# AC005329.1   0.748357  0.710820  0.656970  0.572516  0.691128  0.743787
# AC009107.2   0.772902       NaN       NaN       NaN  0.808072  0.932049
# AC009446.1        NaN       NaN       NaN       NaN       NaN       NaN
# AC010624.5        NaN  0.431254  0.380816  0.706126  0.933139       NaN
# ...               ...       ...       ...       ...       ...       ...
# ZNRD2             NaN  0.711588  0.771315       NaN       NaN  0.569690
# ZRANB2            NaN       NaN       NaN       NaN       NaN       NaN
# ZSCAN10      0.709616  0.832401  0.723404  0.625201  0.708460  0.661804
# ZYX               NaN  0.572816  0.656468  0.622371  0.708259  0.672965
# human_small  0.182558  0.102438  0.181316  0.096820  0.081203  0.073323
#
# id            RHS3595   RHS3596
# batch         batch_2   batch_2
# stage              h9        h9
# lib_type       single    single
# AARS1        0.757770  0.598742
# AC005329.1   0.758632       NaN
# AC009107.2   0.634238  0.742718
# AC009446.1        NaN       NaN
# AC010624.5   0.271185       NaN
# ...               ...       ...
# ZNRD2        0.655364  0.753318
# ZRANB2            NaN       NaN
# ZSCAN10      0.680366       NaN
# ZYX          0.706130  0.771388
# human_small  0.107908  0.244460
#
# [1192 rows x 280 columns]

# %%
def deviation_of_cosine_distance(cosine_dist_df):
    deviation_concat_list = []
    for gene, row in cosine_dist_df.iterrows():
        row = 1-(1 - row)
        deviation = np.sqrt((row.dropna().pow(2).sum()/row.dropna().size))
        deviation_df = pd.DataFrame([deviation], index=[gene], columns=['deviation'])
        deviation_concat_list.append(deviation_df)
    deviation_df = pd.concat(deviation_concat_list)
    return deviation_df
def calculate_heterogeneity_from_pairwise_cosine_distance_matrix(cosine_distance_matrix):
    concat_list = []
    for (batch,stage), subset_cosdist in cosine_distance_matrix.groupby(level=['batch','stage'], axis=1):

        deviation_df = deviation_of_cosine_distance(subset_cosdist)
        deviation_df.columns = pd.MultiIndex.from_tuples([(batch, stage)], names=['batch','stage'])
        concat_list.append(deviation_df)

        """detect_cell_matrix = subset_cosdist.notna().sum(axis=1).to_numpy()
        #print (detect_cell_matrix.shape)
        mean_cosdist = subset_cosdist.mean(axis=1, numeric_only=True)
        diff_cosdist = subset_cosdist.to_numpy() - mean_cosdist.to_frame().to_numpy()
        sqdiff_cosdist = np.nansum(np.square(diff_cosdist), axis=1)
        #print (np.sum(np.isnan(sqdiff_cosdist)))

        avgsqdiff_cosdist = np.nansum(np.square(diff_cosdist), axis=1)/detect_cell_matrix
        sqrtavgsqdiff_cosdist = np.sqrt(avgsqdiff_cosdist)
        out = pd.DataFrame(sqrtavgsqdiff_cosdist, index=subset_cosdist.index, columns=[stage])
        concat_list.append(out)"""

    gene_htg = pd.concat(concat_list, axis=1)
    gene_htg.index.name = "gene"
    return gene_htg

# %%
gene_htg_by_crude_reac = calculate_heterogeneity_from_pairwise_cosine_distance_matrix(cosinde_distance_matrix_from_crude_reac)
gene_htg_by_crude_reac

gene_htg_by_scaled_reac = calculate_heterogeneity_from_pairwise_cosine_distance_matrix(cosinde_distance_matrix_from_scaled_reac)
gene_htg_by_scaled_reac

gene_htg_by_gnorm_reac = calculate_heterogeneity_from_pairwise_cosine_distance_matrix(cosinde_distance_matrix_from_gnorm_reac)
gene_htg_by_gnorm_reac
# Out:
# batch         batch_1                                 batch_2            \
# stage            day0      day1      day7        h9      day0      day1
# gene
# AARS1             NaN       NaN       NaN  0.761867       NaN       NaN
# AC005329.1        NaN       NaN       NaN  0.712555       NaN       NaN
# AC009107.2        NaN       NaN       NaN  0.749618       NaN       NaN
# AC009446.1        NaN       NaN       NaN       NaN       NaN       NaN
# AC010624.5        NaN       NaN       NaN  0.714568       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# ZNRD2             NaN       NaN       NaN  0.670788       NaN       NaN
# ZRANB2            NaN       NaN       NaN       NaN       NaN       NaN
# ZSCAN10           NaN       NaN       NaN  0.729161       NaN       NaN
# ZYX               NaN       NaN       NaN  0.712409       NaN       NaN
# human_small  0.269795  0.245702  0.284558  0.197137  0.288374  0.342664
#
# batch
# stage           day7        h9
# gene
# AARS1            NaN  0.708006
# AC005329.1       NaN  0.670586
# AC009107.2       NaN  0.681716
# AC009446.1       NaN       NaN
# AC010624.5       NaN  0.596731
# ...              ...       ...
# ZNRD2            NaN  0.713621
# ZRANB2           NaN       NaN
# ZSCAN10          NaN  0.716663
# ZYX              NaN  0.688374
# human_small  0.32339  0.137819
#
# [1192 rows x 8 columns]

# %%
gene_htg_by_crude_reac.loc[gene_htg_by_crude_reac[('batch_1','h9')].notna()].sort_values(('batch_1', 'h9')).iloc[0:50]
# Out:
# batch         batch_1                                 batch_2            \
# stage            day0      day1      day7        h9      day0      day1
# gene
# human_small  0.280336  0.263760  0.269408  0.251246  0.303343  0.356692
# MTLN              NaN       NaN       NaN  0.285118       NaN       NaN
# ZNF593            NaN       NaN       NaN  0.338859       NaN       NaN
# RPS29        0.689784  0.580448  0.626591  0.395915  0.638282  0.647558
# RPS27        0.628181  0.590958  0.660686  0.398237  0.645783  0.640803
# RPLP1        0.642426  0.609766  0.677697  0.430786  0.697803  0.663273
# MTRNR2L12    0.420211  0.448404  0.402513  0.440115  0.461073  0.498157
# RSL1D1            NaN       NaN       NaN  0.441770       NaN       NaN
# HNRNPL       0.677982  0.703309  0.635411  0.454045  0.719222  0.706886
# RPL23        0.714774  0.619831  0.708096  0.473436  0.720581  0.694428
# RPS20        0.755022  0.698895  0.735334  0.474643  0.737889  0.702324
# DAZAP1            NaN       NaN       NaN  0.474867       NaN       NaN
# RPL13A       0.639252  0.663001  0.692373  0.475709  0.692206  0.662676
# RPL27        0.687182  0.718264  0.723614  0.484541  0.724037  0.725246
# MT-CO2       0.747332  0.741124  0.714326  0.485231  0.751296  0.736168
# RPLP2        0.707589  0.676003  0.624611  0.489009  0.701986  0.638551
# CTDNEP1           NaN       NaN       NaN  0.491626       NaN       NaN
# RPL37A       0.674049  0.583388  0.656863  0.494878  0.750314  0.674445
# DDX6              NaN       NaN       NaN  0.498946       NaN       NaN
# RPS16        0.702784  0.710158  0.711128  0.502242  0.737649  0.684802
# PITHD1            NaN       NaN       NaN  0.513450       NaN       NaN
# RPL27A       0.709770  0.687196  0.706226  0.516233  0.738338  0.728695
# H4C3         0.534329  0.648547  0.536705  0.520315  0.677190  0.598222
# UGDH              NaN       NaN       NaN  0.522049       NaN       NaN
# AP1B1             NaN       NaN       NaN  0.522856       NaN       NaN
# BRI3              NaN       NaN       NaN  0.526585       NaN       NaN
# PAWR              NaN       NaN       NaN  0.527980       NaN       NaN
# POLR2D            NaN       NaN       NaN  0.529169       NaN       NaN
# RPS12        0.720708  0.738218  0.635898  0.532497  0.704960  0.691664
# RPS18        0.717242  0.702013  0.675823  0.532920  0.680496  0.701182
# RPS2         0.712972  0.650075  0.714968  0.534367  0.698772  0.591240
# RPS17        0.606250       NaN       NaN  0.537697  0.738262       NaN
# YTHDF1            NaN       NaN       NaN  0.539848       NaN       NaN
# AC245033.1   0.751360  0.700351  0.726254  0.540197  0.703887  0.679963
# HSPBP1            NaN       NaN       NaN  0.540748       NaN       NaN
# CDC34             NaN       NaN       NaN  0.543074       NaN       NaN
# MYL6              NaN  0.747530       NaN  0.543869       NaN  0.750936
# RPL23A       0.754416  0.737643  0.693732  0.551564  0.716769  0.707901
# PUSL1             NaN       NaN       NaN  0.552059       NaN       NaN
# SERF2        0.732007  0.695994  0.670353  0.554955  0.704059  0.698699
# UXT               NaN       NaN       NaN  0.555618       NaN       NaN
# NUP43             NaN       NaN       NaN  0.556199       NaN       NaN
# RPL31        0.769842  0.696913  0.706858  0.556774  0.728279  0.710513
# RPS19        0.648193  0.655095  0.671384  0.557856  0.721159  0.601043
# FTL          0.742661  0.719884       NaN  0.563601  0.701053  0.698902
# RPLP0        0.672519  0.642202  0.713289  0.563955  0.702206  0.675227
# H1-3              NaN       NaN       NaN  0.564426       NaN       NaN
# UBA52        0.743556  0.677383  0.692573  0.565818  0.758136  0.802236
# ZFP42             NaN       NaN       NaN  0.566040       NaN       NaN
# RPL36        0.706799  0.711532  0.544136  0.566571  0.736946  0.704813
#
# batch
# stage            day7        h9
# gene
# human_small  0.365779  0.136482
# MTLN              NaN  0.490218
# ZNF593            NaN  0.459838
# RPS29        0.610700  0.528779
# RPS27        0.685399  0.496202
# RPLP1        0.702039  0.514447
# MTRNR2L12    0.548442  0.307418
# RSL1D1            NaN  0.589381
# HNRNPL       0.618900  0.468572
# RPL23        0.732599  0.505136
# RPS20        0.705030  0.509324
# DAZAP1            NaN  0.525399
# RPL13A       0.716275  0.485297
# RPL27        0.724300  0.534561
# MT-CO2       0.682485  0.536422
# RPLP2        0.671062  0.581671
# CTDNEP1           NaN  0.820203
# RPL37A       0.724305  0.513080
# DDX6              NaN  0.800002
# RPS16        0.691419  0.557787
# PITHD1            NaN  0.965198
# RPL27A       0.720530  0.548727
# H4C3         0.666495  0.524046
# UGDH              NaN  0.240675
# AP1B1             NaN  0.666679
# BRI3              NaN  0.719718
# PAWR              NaN  0.705910
# POLR2D            NaN  0.545245
# RPS12        0.718702  0.578346
# RPS18        0.695559  0.607256
# RPS2         0.710577  0.539132
# RPS17             NaN  0.611620
# YTHDF1            NaN  0.641007
# AC245033.1   0.717949  0.581084
# HSPBP1            NaN  0.453149
# CDC34             NaN  0.572979
# MYL6              NaN  0.602094
# RPL23A       0.691978  0.602195
# PUSL1             NaN  0.620622
# SERF2        0.682800  0.607382
# UXT               NaN  0.731789
# NUP43             NaN  0.690450
# RPL31        0.749675  0.625209
# RPS19        0.705113  0.576414
# FTL               NaN  0.578323
# RPLP0        0.705526  0.565308
# H1-3              NaN  0.559178
# UBA52        0.727550  0.476217
# ZFP42             NaN  0.427622
# RPL36        0.681100  0.574302

# %%
hetero_genes = gene_htg_by_crude_reac.loc[gene_htg_by_crude_reac[('batch_1','h9')].notna()].sort_values(('batch_1', 'h9')).iloc[-150:-51].index.to_list()

# %%
gene_htg_by_crude_reac.loc[gene_htg_by_crude_reac[('batch_1','h9')].notna()].sort_values(('batch_1', 'h9')).iloc[-50:-1]
# Out:
# batch      batch_1                          batch_2
# stage         day0      day1 day7        h9    day0      day1 day7        h9
# gene
# TPM3           NaN       NaN  NaN  0.776470     NaN       NaN  NaN  0.746527
# RHOA           NaN       NaN  NaN  0.777494     NaN       NaN  NaN  0.704303
# CIRBP          NaN  0.477936  NaN  0.778847     NaN  0.666234  NaN  0.769530
# SNHG29         NaN       NaN  NaN  0.780379     NaN       NaN  NaN  0.768863
# DDX5           NaN       NaN  NaN  0.781784     NaN       NaN  NaN  0.699118
# HSP90B1        NaN       NaN  NaN  0.782160     NaN       NaN  NaN  0.748855
# SON            NaN       NaN  NaN  0.782813     NaN       NaN  NaN  0.706902
# TACC3          NaN       NaN  NaN  0.784207     NaN       NaN  NaN  0.692683
# SNURF          NaN       NaN  NaN  0.784472     NaN       NaN  NaN  0.721860
# RNF10          NaN       NaN  NaN  0.784706     NaN       NaN  NaN  0.707817
# SUDS3          NaN       NaN  NaN  0.784923     NaN       NaN  NaN  0.657459
# DGUOK          NaN       NaN  NaN  0.785065     NaN       NaN  NaN  0.670575
# SRP9           NaN       NaN  NaN  0.785352     NaN       NaN  NaN  0.727216
# HNRNPH3        NaN       NaN  NaN  0.785613     NaN       NaN  NaN  0.710846
# EEF1G          NaN       NaN  NaN  0.785875     NaN       NaN  NaN  0.663860
# AC009446.1     NaN       NaN  NaN  0.786150     NaN       NaN  NaN  0.539029
# MZT2A          NaN       NaN  NaN  0.786191     NaN       NaN  NaN  0.778947
# COPS6          NaN       NaN  NaN  0.786702     NaN       NaN  NaN  0.743431
# AC010624.5     NaN       NaN  NaN  0.786787     NaN       NaN  NaN  0.559974
# CALM2          NaN       NaN  NaN  0.787286     NaN       NaN  NaN  0.736566
# CBS            NaN       NaN  NaN  0.788468     NaN       NaN  NaN  0.741880
# EIF3G          NaN       NaN  NaN  0.788571     NaN       NaN  NaN  0.732722
# TPM2           NaN       NaN  NaN  0.789043     NaN       NaN  NaN  0.620437
# ERGIC3         NaN       NaN  NaN  0.789699     NaN       NaN  NaN  0.714298
# CAP1           NaN       NaN  NaN  0.791254     NaN       NaN  NaN  0.718091
# AC117378.1     NaN       NaN  NaN  0.791905     NaN       NaN  NaN  0.767359
# EIF5A          NaN       NaN  NaN  0.793374     NaN       NaN  NaN  0.734818
# ARPC3          NaN       NaN  NaN  0.793502     NaN       NaN  NaN  0.694472
# PSMA3          NaN       NaN  NaN  0.794214     NaN       NaN  NaN  0.759934
# GFUS           NaN       NaN  NaN  0.794626     NaN       NaN  NaN  0.660058
# TRAP1          NaN       NaN  NaN  0.800883     NaN       NaN  NaN  0.659650
# NUDT1          NaN       NaN  NaN  0.803906     NaN       NaN  NaN  0.528620
# EI24           NaN       NaN  NaN  0.808113     NaN       NaN  NaN  0.532284
# SMARCE1        NaN       NaN  NaN  0.808939     NaN       NaN  NaN  0.652961
# DHCR7          NaN       NaN  NaN  0.809168     NaN       NaN  NaN  0.559224
# TMSB15A        NaN       NaN  NaN  0.813322     NaN       NaN  NaN  0.683184
# DNAJB6         NaN       NaN  NaN  0.815163     NaN       NaN  NaN  0.750830
# DAD1           NaN       NaN  NaN  0.819798     NaN       NaN  NaN  0.855290
# ZRANB2         NaN       NaN  NaN  0.820968     NaN       NaN  NaN  0.687041
# HDAC2          NaN       NaN  NaN  0.825055     NaN       NaN  NaN  0.690558
# RBM17          NaN       NaN  NaN  0.827111     NaN       NaN  NaN  0.759950
# TOMM20         NaN       NaN  NaN  0.827319     NaN       NaN  NaN  0.687268
# PSMD13         NaN       NaN  NaN  0.827572     NaN       NaN  NaN  0.707602
# KIF22          NaN       NaN  NaN  0.832334     NaN       NaN  NaN  0.500351
# AC092490.1     NaN       NaN  NaN  0.857100     NaN       NaN  NaN  0.980842
# ACAA2          NaN       NaN  NaN  0.875963     NaN       NaN  NaN  0.846582
# SPINT2         NaN       NaN  NaN  0.878631     NaN       NaN  NaN  0.735260
# NSUN5          NaN       NaN  NaN  0.912550     NaN       NaN  NaN  0.571258
# HERC2          NaN       NaN  NaN  0.932307     NaN       NaN  NaN  0.713582

# %%
gene_htg_by_crude_reac.loc['ATP5F1E'].index
# Out:
# MultiIndex([('batch_1', 'day0'),
#             ('batch_1', 'day1'),
#             ('batch_1', 'day7'),
#             ('batch_1',   'h9'),
#             ('batch_2', 'day0'),
#             ('batch_2', 'day1'),
#             ('batch_2', 'day7'),
#             ('batch_2',   'h9')],
#            names=['batch', 'stage'])

# %% [markdown]
# ### 5.3 Rsq propotion of each gene

# %%
h9_rsq_df = wide_rsq_df[[('batch_1','h9')]]
h9_rsq_df.columns = ['rsq']
sns.kdeplot(data=h9_rsq_df.reset_index(), x="rsq")
plt.show()

# %%
print (
    np.percentile(h9_rsq_df['rsq'].dropna(), 95),
    np.percentile(h9_rsq_df['rsq'].dropna(), 75),    
    np.percentile(h9_rsq_df['rsq'].dropna(), 50),    
    np.percentile(h9_rsq_df['rsq'].dropna(), 25),
    np.percentile(h9_rsq_df['rsq'].dropna(), 5),    )
# Out:
# 0.741685473685938 0.4679571350313938 0.23440777600257062 0.06238843962302864 0.002358545551939774

# %% [markdown]
# ### 5.4 GO enrichment_table

# %%
h9_htg = gene_htg_by_crude_reac.loc[:, ('batch_1','h9')].to_frame('heterogeneity').dropna()
h9_htg_homo_10pct = np.percentile(h9_htg['heterogeneity'].dropna(), 10)
h9_htg_homo_25pct = np.percentile(h9_htg['heterogeneity'].dropna(), 25)
h9_htg_homo_75pct = np.percentile(h9_htg['heterogeneity'].dropna(), 75)
h9_htg_homo_90pct = np.percentile(h9_htg['heterogeneity'].dropna(), 90)

h9_htg.to_csv("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/total_h9_htg_geneset.csv")
h9_htg.loc[h9_htg['heterogeneity']<h9_htg_homo_10pct].to_csv("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/homo_10pct_h9_htg_geneset.csv")
h9_htg.loc[h9_htg['heterogeneity']<h9_htg_homo_25pct].to_csv("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/homo_25pct_h9_htg_geneset.csv")
h9_htg.loc[h9_htg['heterogeneity']>h9_htg_homo_75pct].to_csv("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/homo_75pct_h9_htg_geneset.csv")
h9_htg.loc[h9_htg['heterogeneity']>h9_htg_homo_90pct].to_csv("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/homo_90pct_h9_htg_geneset.csv")

# %%
##

# %%
import goatools

# %%
from unipressed import UniprotkbClient, UniparcClient, IdMappingClient

# %%
request = IdMappingClient.submit(
    source="GeneCards", dest="UniProtKB", ids=h9_htg.index.unique().to_list()
)
time.sleep(1.0)

# %% [markdown]
# ### Convert gene name to Uniport id

# %%
request = IdMappingClient.submit(
    source="UniProtKB_AC-ID", dest="Gene_Name", ids={"A1L190", "A0JP26", "A0PK11"})

# %%
request = IdMappingClient.submit(
    source="GeneCards", dest="UniProtKB", ids=["MTCH2", "CLRN2", "SYCE3","POTEB3"]
)
time.sleep(1.0)

# %%
list(request.each_result())
# Out:
# [{'from': 'MTCH2', 'to': 'Q9Y6C9'},
#  {'from': 'CLRN2', 'to': 'A0PK11'},
#  {'from': 'SYCE3', 'to': 'A1L190'},
#  {'from': 'POTEB3', 'to': 'A0JP26'}]

# %%
UniprotkbClient.search(query={
    "and_": [
        {"family": "kinase"},
        {"organism_id": "9606"},
    ]
})
# Out:
# Search(query={'and_': [{'family': 'kinase'}, {'organism_id': '9606'}]}, dataset='uniprotkb', format='json', fields=None, include_isoform=True, size=500)

# %% [markdown]
# #### 5.5 convert genes to uniport id

# %%
request = IdMappingClient.submit(
    source="GeneCards", dest="UniProtKB", ids=h9_htg.loc[h9_htg['heterogeneity']<h9_htg_homo_10pct].index.unique().to_list()
)
time.sleep(1.0)

# %%
len(list(request.each_result()))
# Out:
# 1156

# %%
request = IdMappingClient.submit(
    source="GeneCards", dest="UniProtKB", ids=['MALAT1']
)
time.sleep(1.0)
len(list(request.each_result()))
# Out:
# 0

# %% [markdown]
# #### 5.6 GO by goenrich

# %% [markdown]
# ##### 5.6.1 convert gene symbol to entrez id

# %%
import biomart

def get_ensembl_mappings():                                   
    # Set up connection to server                                               
    server = biomart.BiomartServer( "http://uswest.ensembl.org/biomart" )      
    mart = server.datasets['hsapiens_gene_ensembl']                            
    
    #server.show_databases()
    #server.show_datasets() # uses pprint behind the scenes
                                                                                
    # List the types of data we want                                            
    attributes = ['ensembl_transcript_id', 'gene_biotype', 'rfam', 'external_gene_name', 'entrezgene_id', ##go_id
                  'ensembl_gene_id', 'ensembl_peptide_id']
                                                                                
    # Get the mapping between the attributes                                    
    response = mart.search({'attributes': attributes})                          
    data = response.raw.data.decode('ascii')                                    
                                                                                
    ensembl_to_genesymbol = {}                                                  
    # Store the data in a dict                                                  
    for line in data.splitlines():                                              
        line = line.split('\t')                                                 
        # The entries are in the same order as in the `attributes` variable
        transcript_id = line[0]                                                 
        gene_symbol = line[1]                                                   
        ensembl_gene = line[2]                                                  
        ensembl_peptide = line[3]                                               
                                                                                
        # Some of these keys may be an empty string. If you want, you can 
        # avoid having a '' key in your dict by ensuring the 
        # transcript/gene/peptide ids have a nonzero length before
        # adding them to the dict
        ensembl_to_genesymbol[transcript_id] = gene_symbol                      
        ensembl_to_genesymbol[ensembl_gene] = gene_symbol                       
        ensembl_to_genesymbol[ensembl_peptide] = gene_symbol                
                                                                                
    return mart, ensembl_to_genesymbol
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 import biomart
#       3 def get_ensembl_mappings():
#       4     # Set up connection to server
#       5     server = biomart.BiomartServer( "http://uswest.ensembl.org/biomart" )
#
# ModuleNotFoundError: No module named 'biomart'

# %%
mart, ensembl_to_gene_symbol = get_ensembl_mappings()

# %%
n = 0
for k,d in ensembl_to_gene_symbol.items():
    print (k, d)
    n += 1
    if n == 50:
        break
# Out:
# ENST00000387314 Mt_tRNA
#  protein_coding
# MT-TF Mt_tRNA
# ENST00000389680 Mt_rRNA
# MT-RNR1 Mt_rRNA
# ENST00000387342 Mt_tRNA
# MT-TV Mt_tRNA
# ENST00000387347 Mt_rRNA
# MT-RNR2 Mt_rRNA
# ENST00000386347 Mt_tRNA
# MT-TL1 Mt_tRNA
# ENST00000361390 protein_coding
# MT-ND1 protein_coding
# ENST00000387365 Mt_tRNA
# MT-TI Mt_tRNA
# ENST00000387372 Mt_tRNA
# MT-TQ Mt_tRNA
# ENST00000387377 Mt_tRNA
# MT-TM Mt_tRNA
# ENST00000361453 protein_coding
# MT-ND2 protein_coding
# ENST00000387382 Mt_tRNA
# MT-TW Mt_tRNA
# ENST00000387392 Mt_tRNA
# MT-TA Mt_tRNA
# ENST00000387400 Mt_tRNA
# MT-TN Mt_tRNA
# ENST00000387405 Mt_tRNA
# MT-TC Mt_tRNA
# ENST00000387409 Mt_tRNA
# MT-TY Mt_tRNA
# ENST00000361624 protein_coding
# MT-CO1 protein_coding
# ENST00000387416 Mt_tRNA
# MT-TS1 Mt_tRNA
# ENST00000387419 Mt_tRNA
# MT-TD Mt_tRNA
# ENST00000361739 protein_coding
# MT-CO2 protein_coding
# ENST00000387421 Mt_tRNA
# MT-TK Mt_tRNA
# ENST00000361851 protein_coding
# MT-ATP8 protein_coding
# ENST00000361899 protein_coding
# MT-ATP6 protein_coding
# ENST00000362079 protein_coding
# MT-CO3 protein_coding
# ENST00000387429 Mt_tRNA
# MT-TG Mt_tRNA
# ENST00000361227 protein_coding

# %%
pd.DataFrame.from_dict(ensembl_to_gene_symbol)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [110], line 1
# ----> 1 pd.DataFrame.from_dict(ensembl_to_gene_symbol)
#
# File S:\Miniconda\lib\site-packages\pandas\core\frame.py:1677, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1674     raise ValueError("only recognize index or columns for orient")
#    1676 if orient != "tight":
# -> 1677     return cls(data, index=index, columns=columns, dtype=dtype)
#    1678 else:
#    1679     realdata = data["data"]
#
# File S:\Miniconda\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File S:\Miniconda\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File S:\Miniconda\lib\site-packages\pandas\core\internals\construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File S:\Miniconda\lib\site-packages\pandas\core\internals\construction.py:664, in _extract_index(data)
#     661         raise ValueError("Per-column arrays must each be 1-dimensional")
#     663 if not indexes and not raw_lengths:
# --> 664     raise ValueError("If using all scalar values, you must pass an index")
#     666 elif have_series:
#     667     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
server.show_datasets() # uses pprint behind the scenes
# Out:
# {'abrachyrhynchus_gene_ensembl': Pink-footed goose genes (ASM259213v1),
#  'abrachyrhynchus_genomic_sequence': Pink-footed goose sequences (ASM259213v1),
#  'acalliptera_gene_ensembl': Eastern happy genes (fAstCal1.2),
#  'acalliptera_genomic_sequence': Eastern happy sequences (fAstCal1.2),
#  'acarolinensis_gene_ensembl': Green anole genes (AnoCar2.0v2),
#  'acarolinensis_genomic_sequence': Green anole sequences (AnoCar2.0v2),
#  'acchrysaetos_gene_ensembl': Golden eagle genes (bAquChr1.2),
#  'acchrysaetos_genomic_sequence': Golden eagle sequences (bAquChr1.2),
#  'acitrinellus_gene_ensembl': Midas cichlid genes (Midas_v5),
#  'acitrinellus_genomic_sequence': Midas cichlid sequences (Midas_v5),
#  'amelanoleuca_gene_ensembl': Giant panda genes (ASM200744v2),
#  'amelanoleuca_genomic_sequence': Giant panda sequences (ASM200744v2),
#  'amexicanus_gene_ensembl': Mexican tetra genes (Astyanax_mexicanus-2.0),
#  'amexicanus_genomic_sequence': Mexican tetra sequences (Astyanax_mexicanus-2.0),
#  'anancymaae_gene_ensembl': Ma's night monkey genes (Anan_2.0),
#  'anancymaae_genomic_sequence': Ma's night monkey sequences (Anan_2.0),
#  'aocellaris_gene_ensembl': Clown anemonefish genes (AmpOce1.0),
#  'aocellaris_genomic_sequence': Clown anemonefish sequences (AmpOce1.0),
#  'apercula_gene_ensembl': Orange clownfish genes (Nemo_v1),
#  'apercula_genomic_sequence': Orange clownfish sequences (Nemo_v1),
#  'aplatyrhynchos_gene_ensembl': Mallard genes (ASM874695v1),
#  'aplatyrhynchos_genomic_sequence': Mallard sequences (ASM874695v1),
#  'apolyacanthus_gene_ensembl': Spiny chromis genes (ASM210954v1),
#  'apolyacanthus_genomic_sequence': Spiny chromis sequences (ASM210954v1),
#  'applatyrhynchos_gene_ensembl': Duck genes (CAU_duck1.0),
#  'applatyrhynchos_genomic_sequence': Duck sequences (CAU_duck1.0),
#  'atestudineus_gene_ensembl': Climbing perch genes (fAnaTes1.2),
#  'atestudineus_genomic_sequence': Climbing perch sequences (fAnaTes1.2),
#  'bbbison_gene_ensembl': American bison genes (Bison_UMD1.0),
#  'bbbison_genomic_sequence': American bison sequences (Bison_UMD1.0),
#  'bgrunniens_gene_ensembl': Domestic yak genes (LU_Bosgru_v3.0),
#  'bgrunniens_genomic_sequence': Domestic yak sequences (LU_Bosgru_v3.0),
#  'bihybrid_gene_ensembl': Hybrid - Bos Indicus genes (UOA_Brahman_1),
#  'bihybrid_genomic_sequence': Hybrid - Bos Indicus sequences (UOA_Brahman_1),
#  'bmusculus_gene_ensembl': Blue whale genes (mBalMus1.v2),
#  'bmusculus_genomic_sequence': Blue whale sequences (mBalMus1.v2),
#  'bmutus_gene_ensembl': Wild yak genes (BosGru_v2.0),
#  'bmutus_genomic_sequence': Wild yak sequences (BosGru_v2.0),
#  'bsplendens_gene_ensembl': Siamese fighting fish genes (fBetSpl5.2),
#  'bsplendens_genomic_sequence': Siamese fighting fish sequences (fBetSpl5.2),
#  'btaurus_gene_ensembl': Cow genes (ARS-UCD1.2),
#  'btaurus_genomic_sequence': Cow sequences (ARS-UCD1.2),
#  'btaurus_qtl_feature': qtl_feature,
#  'btaurus_snp': Cow Short Variants (SNPs and indels excluding flagged variants) (ARS-UCD1.2),
#  'btaurus_structvar': Cow Structural Variants (ARS-UCD1.2),
#  'cabingdonii_gene_ensembl': Abingdon island giant tortoise genes (ASM359739v1),
#  'cabingdonii_genomic_sequence': Abingdon island giant tortoise sequences (ASM359739v1),
#  'catys_gene_ensembl': Sooty mangabey genes (Caty_1.0),
#  'catys_genomic_sequence': Sooty mangabey sequences (Caty_1.0),
#  'cauratus_gene_ensembl': Goldfish genes (ASM336829v1),
#  'cauratus_genomic_sequence': Goldfish sequences (ASM336829v1),
#  'ccapucinus_gene_ensembl': Capuchin genes (Cebus_imitator-1.0),
#  'ccapucinus_genomic_sequence': Capuchin sequences (Cebus_imitator-1.0),
#  'ccarpio_gene_ensembl': Common carp genes (common_carp_genome),
#  'ccarpio_genomic_sequence': Common carp sequences (common_carp_genome),
#  'cccarpio_gene_ensembl': Common carp genes (Cypcar_WagV4.0),
#  'cccarpio_genomic_sequence': Common carp sequences (Cypcar_WagV4.0),
#  'cdromedarius_gene_ensembl': Arabian camel genes (CamDro2),
#  'cdromedarius_genomic_sequence': Arabian camel sequences (CamDro2),
#  'celegans_gene_ensembl': Caenorhabditis elegans (PRJNA13758) genes (WBcel235),
#  'celegans_genomic_sequence': Caenorhabditis elegans (PRJNA13758) sequences (WBcel235),
#  'cgchok1gshd_gene_ensembl': Chinese hamster CHOK1GS genes (CHOK1GS_HDv1),
#  'cgchok1gshd_genomic_sequence': Chinese hamster CHOK1GS sequences (CHOK1GS_HDv1),
#  'cgobio_gene_ensembl': Channel bull blenny genes (fCotGob3.1),
#  'cgobio_genomic_sequence': Channel bull blenny sequences (fCotGob3.1),
#  'charengus_gene_ensembl': Atlantic herring genes (Ch_v2.0.2),
#  'charengus_genomic_sequence': Atlantic herring sequences (Ch_v2.0.2),
#  'chircus_gene_ensembl': Goat genes (ARS1),
#  'chircus_genomic_sequence': Goat sequences (ARS1),
#  'chircus_snp': Goat Short Variants (SNPs and indels excluding flagged variants) (ARS1),
#  'choffmanni_gene_ensembl': Sloth genes (choHof1),
#  'choffmanni_genomic_sequence': Sloth sequences (choHof1),
#  'chyarkandensis_gene_ensembl': Yarkand deer genes (CEY_v1),
#  'chyarkandensis_genomic_sequence': Yarkand deer sequences (CEY_v1),
#  'cintestinalis_gene_ensembl': C.intestinalis genes (KH),
#  'cintestinalis_genomic_sequence': C.intestinalis sequences (KH),
#  'cjacchus_gene_ensembl': White-tufted-ear marmoset genes (mCalJac1.pat.X),
#  'cjacchus_genomic_sequence': White-tufted-ear marmoset sequences (mCalJac1.pat.X),
#  'cjaponica_gene_ensembl': Japanese quail genes (Coturnix_japonica_2.0),
#  'cjaponica_genomic_sequence': Japanese quail sequences (Coturnix_japonica_2.0),
#  'clanigera_gene_ensembl': Long-tailed chinchilla genes (ChiLan1.0),
#  'clanigera_genomic_sequence': Long-tailed chinchilla sequences (ChiLan1.0),
#  'cldingo_gene_ensembl': Dingo genes (ASM325472v1),
#  'cldingo_genomic_sequence': Dingo sequences (ASM325472v1),
#  'clfamiliaris_gene_ensembl': Dog genes (ROS_Cfam_1.0),
#  'clfamiliaris_genomic_sequence': Dog sequences (ROS_Cfam_1.0),
#  'clfamiliaris_snp': Dog Short Variants (SNPs and indels excluding flagged variants) (ROS_Cfam_1.0),
#  'clfamiliaris_structvar': Dog Structural Variants (ROS_Cfam_1.0),
#  'closure_BFO': ontology,
#  'closure_BTO': ontology,
#  'closure_CHEBI': ontology,
#  'closure_CL': ontology,
#  'closure_ECO': ontology,
#  'closure_EFO': ontology,
#  'closure_EO': ontology,
#  'closure_FYPO': ontology,
#  'closure_GO': ontology,
#  'closure_GRO': ontology,
#  'closure_MOD': ontology,
#  'closure_OGMS': ontology,
#  'closure_PATO': ontology,
#  'closure_PBO': ontology,
#  'closure_PBQ': ontology,
#  'closure_PECO': ontology,
#  'closure_PHI': ontology,
#  'closure_PO': ontology,
#  'closure_SO': ontology,
#  'closure_SO_mini': ontology_mini,
#  'closure_SO_motif': ontology_motif,
#  'closure_SO_regulation': ontology_regulation,
#  'closure_TO': ontology,
#  'closure_UO': ontology,
#  'clumpus_gene_ensembl': Lumpfish genes (fCycLum1.pri),
#  'clumpus_genomic_sequence': Lumpfish sequences (fCycLum1.pri),
#  'cmilii_gene_ensembl': Elephant shark genes (Callorhinchus_milii-6.1.3),
#  'cmilii_genomic_sequence': Elephant shark sequences (Callorhinchus_milii-6.1.3),
#  'cpbellii_gene_ensembl': Painted turtle genes (Chrysemys_picta_bellii-3.0.3),
#  'cpbellii_genomic_sequence': Painted turtle sequences (Chrysemys_picta_bellii-3.0.3),
#  'cporcellus_gene_ensembl': Guinea Pig genes (Cavpor3.0),
#  'cporcellus_genomic_sequence': Guinea Pig sequences (Cavpor3.0),
#  'cporosus_gene_ensembl': Australian saltwater crocodile genes (CroPor_comp1),
#  'cporosus_genomic_sequence': Australian saltwater crocodile sequences (CroPor_comp1),
#  'csabaeus_gene_ensembl': Vervet-AGM genes (ChlSab1.1),
#  'csabaeus_genomic_sequence': Vervet-AGM sequences (ChlSab1.1),
#  'csavignyi_gene_ensembl': C.savignyi genes (CSAV 2.0),
#  'csavignyi_genomic_sequence': C.savignyi sequences (CSAV 2.0),
#  'csemilaevis_gene_ensembl': Tongue sole genes (Cse_v1.0),
#  'csemilaevis_genomic_sequence': Tongue sole sequences (Cse_v1.0),
#  'csyrichta_gene_ensembl': Tarsier genes (Tarsius_syrichta-2.0.1),
#  'csyrichta_genomic_sequence': Tarsier sequences (Tarsius_syrichta-2.0.1),
#  'cvariegatus_gene_ensembl': Sheepshead minnow genes (C_variegatus-1.0),
#  'cvariegatus_genomic_sequence': Sheepshead minnow sequences (C_variegatus-1.0),
#  'cwagneri_gene_ensembl': Chacoan peccary genes (CatWag_v2_BIUU_UCD),
#  'cwagneri_genomic_sequence': Chacoan peccary sequences (CatWag_v2_BIUU_UCD),
#  'dclupeoides_gene_ensembl': Denticle herring genes (fDenClu1.1),
#  'dclupeoides_genomic_sequence': Denticle herring sequences (fDenClu1.1),
#  'dlabrax_gene_ensembl': European seabass genes (dlabrax2021),
#  'dlabrax_genomic_sequence': European seabass sequences (dlabrax2021),
#  'dleucas_gene_ensembl': Beluga whale genes (ASM228892v3),
#  'dleucas_genomic_sequence': Beluga whale sequences (ASM228892v3),
#  'dmelanogaster_gene_ensembl': Drosophila melanogaster genes (BDGP6.32),
#  'dmelanogaster_genomic_sequence': Drosophila melanogaster sequences (BDGP6.32),
#  'dmelanogaster_karyotype_end': karyotype_end,
#  'dmelanogaster_karyotype_start': karyotype_start,
#  'dnovemcinctus_gene_ensembl': Armadillo genes (Dasnov3.0),
#  'dnovemcinctus_genomic_sequence': Armadillo sequences (Dasnov3.0),
#  'dordii_gene_ensembl': Kangaroo rat genes (Dord_2.0),
#  'dordii_genomic_sequence': Kangaroo rat sequences (Dord_2.0),
#  'drerio_gene_ensembl': Zebrafish genes (GRCz11),
#  'drerio_genomic_sequence': Zebrafish sequences (GRCz11),
#  'drerio_snp': Zebrafish Short Variants (SNPs and indels excluding flagged variants) (GRCz11),
#  'drerio_structvar': Zebrafish Structural Variants (GRCz11),
#  'eaasinus_gene_ensembl': Donkey genes (ASM303372v1),
#  'eaasinus_genomic_sequence': Donkey sequences (ASM303372v1),
#  'eburgeri_gene_ensembl': Hagfish genes (Eburgeri_3.2),
#  'eburgeri_genomic_sequence': Hagfish sequences (Eburgeri_3.2),
#  'ecaballus_gene_ensembl': Horse genes (EquCab3.0),
#  'ecaballus_genomic_sequence': Horse sequences (EquCab3.0),
#  'ecaballus_qtl_feature': qtl_feature,
#  'ecaballus_snp': Horse Short Variants (SNPs and indels excluding flagged variants) (EquCab3.0),
#  'ecaballus_structvar': Horse Structural Variants (EquCab3.0),
#  'ecalabaricus_gene_ensembl': Reedfish genes (fErpCal1.1),
#  'ecalabaricus_genomic_sequence': Reedfish sequences (fErpCal1.1),
#  'eelectricus_gene_ensembl': Electric eel genes (Ee_SOAP_WITH_SSPACE),
#  'eelectricus_genomic_sequence': Electric eel sequences (Ee_SOAP_WITH_SSPACE),
#  'eeuropaeus_gene_ensembl': Hedgehog genes (eriEur1),
#  'eeuropaeus_genomic_sequence': Hedgehog sequences (eriEur1),
#  'elucius_gene_ensembl': Northern pike genes (Eluc_v4),
#  'elucius_genomic_sequence': Northern pike sequences (Eluc_v4),
#  'etelfairi_gene_ensembl': Lesser hedgehog tenrec genes (TENREC),
#  'etelfairi_genomic_sequence': Lesser hedgehog tenrec sequences (TENREC),
#  'falbicollis_gene_ensembl': Collared flycatcher genes (FicAlb1.5),
#  'falbicollis_genomic_sequence': Collared flycatcher sequences (FicAlb1.5),
#  'fcatus_gene_ensembl': Cat genes (Felis_catus_9.0),
#  'fcatus_genomic_sequence': Cat sequences (Felis_catus_9.0),
#  'fcatus_snp': Cat Short Variants (SNPs and indels excluding flagged variants) (Felis_catus_9.0),
#  'fheteroclitus_gene_ensembl': Mummichog genes (Fundulus_heteroclitus-3.0.2),
#  'fheteroclitus_genomic_sequence': Mummichog sequences (Fundulus_heteroclitus-3.0.2),
#  'gaculeatus_gene_ensembl': Stickleback genes (BROAD S1),
#  'gaculeatus_genomic_sequence': Stickleback sequences (BROAD S1),
#  'gaculeatus_marker_end': marker_feature_end,
#  'gaculeatus_marker_start': marker_feature,
#  'gevgoodei_gene_ensembl': Goodes thornscrub tortoise genes (rGopEvg1_v1.p),
#  'gevgoodei_genomic_sequence': Goodes thornscrub tortoise sequences (rGopEvg1_v1.p),
#  'gfortis_gene_ensembl': Medium ground-finch genes (GeoFor_1.0),
#  'gfortis_genomic_sequence': Medium ground-finch sequences (GeoFor_1.0),
#  'ggallus_gene_ensembl': Chicken (maternal Broiler) genes (bGalGal1.mat.broiler.GRCg7b),
#  'ggallus_genomic_sequence': Chicken (maternal Broiler) sequences (bGalGal1.mat.broiler.GRCg7b),
#  'ggallus_qtl_feature': qtl_feature,
#  'ggallus_snp': Chicken (maternal Broiler) Short Variants (SNPs and indels excluding flagged variants) (bGalGal1.mat.broiler.GRCg7b),
#  'ggorilla_gene_ensembl': Gorilla genes (gorGor4),
#  'ggorilla_genomic_sequence': Gorilla sequences (gorGor4),
#  'gmorhua_gene_ensembl': Atlantic cod genes (gadMor3.0),
#  'gmorhua_genomic_sequence': Atlantic cod sequences (gadMor3.0),
#  'hburtoni_gene_ensembl': Burton's mouthbrooder genes (AstBur1.0),
#  'hburtoni_genomic_sequence': Burton's mouthbrooder sequences (AstBur1.0),
#  'hcomes_gene_ensembl': Tiger tail seahorse genes (H_comes_QL1_v1),
#  'hcomes_genomic_sequence': Tiger tail seahorse sequences (H_comes_QL1_v1),
#  'hgfemale_gene_ensembl': Naked mole-rat female genes (HetGla_female_1.0),
#  'hgfemale_genomic_sequence': Naked mole-rat female sequences (HetGla_female_1.0),
#  'hhucho_gene_ensembl': Huchen genes (ASM331708v1),
#  'hhucho_genomic_sequence': Huchen sequences (ASM331708v1),
#  'hsapiens_encode': encode,
#  'hsapiens_external_feature': Human Other Regulatory Regions (GRCh38.p13),
#  'hsapiens_gene_ensembl': Human genes (GRCh38.p13),
#  'hsapiens_genomic_sequence': Human sequences (GRCh38.p13),
#  'hsapiens_karyotype_end': karyotype_end,
#  'hsapiens_karyotype_start': karyotype_start,
#  'hsapiens_marker_end': marker_feature_end,
#  'hsapiens_marker_start': marker_feature,
#  'hsapiens_mirna_target_feature': Human miRNA Target Regions (GRCh38.p13),
#  'hsapiens_regulatory_feature': Human Regulatory Features (GRCh38.p13),
#  'hsapiens_snp': Human Short Variants (SNPs and indels excluding flagged variants) (GRCh38.p13),
#  'hsapiens_snp_som': Human Somatic Short Variants (SNPs and indels excluding flagged variants) (GRCh38.p13),
#  'hsapiens_structvar': Human Structural Variants (GRCh38.p13),
#  'hsapiens_structvar_som': Human Somatic Structural Variants (GRCh38.p13),
#  'ipunctatus_gene_ensembl': Channel catfish genes (IpCoco_1.2),
#  'ipunctatus_genomic_sequence': Channel catfish sequences (IpCoco_1.2),
#  'itridecemlineatus_gene_ensembl': Squirrel genes (SpeTri2.0),
#  'itridecemlineatus_genomic_sequence': Squirrel sequences (SpeTri2.0),
#  'jjaculus_gene_ensembl': Lesser Egyptian jerboa genes (JacJac1.0),
#  'jjaculus_genomic_sequence': Lesser Egyptian jerboa sequences (JacJac1.0),
#  'kmarmoratus_gene_ensembl': Mangrove rivulus genes (ASM164957v1),
#  'kmarmoratus_genomic_sequence': Mangrove rivulus sequences (ASM164957v1),
#  'lafricana_gene_ensembl': Elephant genes (Loxafr3.0),
#  'lafricana_genomic_sequence': Elephant sequences (Loxafr3.0),
#  'lbergylta_gene_ensembl': Ballan wrasse genes (BallGen_V1),
#  'lbergylta_genomic_sequence': Ballan wrasse sequences (BallGen_V1),
#  'lcalcarifer_gene_ensembl': Barramundi perch genes (ASB_HGAPassembly_v1),
#  'lcalcarifer_genomic_sequence': Barramundi perch sequences (ASB_HGAPassembly_v1),
#  'lchalumnae_gene_ensembl': Coelacanth genes (LatCha1),
#  'lchalumnae_genomic_sequence': Coelacanth sequences (LatCha1),
#  'lcrocea_gene_ensembl': Large yellow croaker genes (L_crocea_2.0),
#  'lcrocea_genomic_sequence': Large yellow croaker sequences (L_crocea_2.0),
#  'llaticaudata_gene_ensembl': Blue-ringed sea krait genes (latLat_1.0),
#  'llaticaudata_genomic_sequence': Blue-ringed sea krait sequences (latLat_1.0),
#  'lleishanense_gene_ensembl': Leishan spiny toad genes (ASM966780v1),
#  'lleishanense_genomic_sequence': Leishan spiny toad sequences (ASM966780v1),
#  'loculatus_gene_ensembl': Spotted gar genes (LepOcu1),
#  'loculatus_genomic_sequence': Spotted gar sequences (LepOcu1),
#  'marmatus_gene_ensembl': Zig-zag eel genes (fMasArm1.2),
#  'marmatus_genomic_sequence': Zig-zag eel sequences (fMasArm1.2),
#  'mauratus_gene_ensembl': Golden Hamster genes (MesAur1.0),
#  'mauratus_genomic_sequence': Golden Hamster sequences (MesAur1.0),
#  'mcaroli_gene_ensembl': Ryukyu mouse genes (CAROLI_EIJ_v1.1),
#  'mcaroli_genomic_sequence': Ryukyu mouse sequences (CAROLI_EIJ_v1.1),
#  'mdomestica_gene_ensembl': Opossum genes (ASM229v1),
#  'mdomestica_genomic_sequence': Opossum sequences (ASM229v1),
#  'mdomestica_snp': Opossum Short Variants (SNPs and indels excluding flagged variants) (ASM229v1),
#  'mfascicularis_gene_ensembl': Crab-eating macaque genes (Macaca_fascicularis_6.0),
#  'mfascicularis_genomic_sequence': Crab-eating macaque sequences (Macaca_fascicularis_6.0),
#  'mgallopavo_gene_ensembl': Turkey genes (Turkey_5.1),
#  'mgallopavo_genomic_sequence': Turkey sequences (Turkey_5.1),
#  'mgallopavo_snp': Turkey Short Variants (SNPs and indels excluding flagged variants) (Turkey_5.1),
#  'mleucophaeus_gene_ensembl': Drill genes (Mleu.le_1.0),
#  'mleucophaeus_genomic_sequence': Drill sequences (Mleu.le_1.0),
#  'mlucifugus_gene_ensembl': Microbat genes (Myoluc2.0),
#  'mlucifugus_genomic_sequence': Microbat sequences (Myoluc2.0),
#  'mm129s1svimj_gene_ensembl': Mouse 129S1/SvImJ genes (129S1_SvImJ_v1),
#  'mm129s1svimj_genomic_sequence': Mouse 129S1/SvImJ sequences (129S1_SvImJ_v1),
#  'mmaj_gene_ensembl': Mouse A/J genes (A_J_v1),
#  'mmaj_genomic_sequence': Mouse A/J sequences (A_J_v1),
#  'mmakrj_gene_ensembl': Mouse AKR/J genes (AKR_J_v1),
#  'mmakrj_genomic_sequence': Mouse AKR/J sequences (AKR_J_v1),
#  'mmbalbcj_gene_ensembl': Mouse BALB/cJ genes (BALB_cJ_v1),
#  'mmbalbcj_genomic_sequence': Mouse BALB/cJ sequences (BALB_cJ_v1),
#  'mmc3hhej_gene_ensembl': Mouse C3H/HeJ genes (C3H_HeJ_v1),
#  'mmc3hhej_genomic_sequence': Mouse C3H/HeJ sequences (C3H_HeJ_v1),
#  'mmc57bl6nj_gene_ensembl': Mouse C57BL/6NJ genes (C57BL_6NJ_v1),
#  'mmc57bl6nj_genomic_sequence': Mouse C57BL/6NJ sequences (C57BL_6NJ_v1),
#  'mmcasteij_gene_ensembl': Mouse CAST/EiJ genes (CAST_EiJ_v1),
#  'mmcasteij_genomic_sequence': Mouse CAST/EiJ sequences (CAST_EiJ_v1),
#  'mmcbaj_gene_ensembl': Mouse CBA/J genes (CBA_J_v1),
#  'mmcbaj_genomic_sequence': Mouse CBA/J sequences (CBA_J_v1),
#  'mmdba2j_gene_ensembl': Mouse DBA/2J genes (DBA_2J_v1),
#  'mmdba2j_genomic_sequence': Mouse DBA/2J sequences (DBA_2J_v1),
#  'mmfvbnj_gene_ensembl': Mouse FVB/NJ genes (FVB_NJ_v1),
#  'mmfvbnj_genomic_sequence': Mouse FVB/NJ sequences (FVB_NJ_v1),
#  'mmlpj_gene_ensembl': Mouse LP/J genes (LP_J_v1),
#  'mmlpj_genomic_sequence': Mouse LP/J sequences (LP_J_v1),
#  'mmmarmota_gene_ensembl': Alpine marmot genes (marMar2.1),
#  'mmmarmota_genomic_sequence': Alpine marmot sequences (marMar2.1),
#  'mmnodshiltj_gene_ensembl': Mouse NOD/ShiLtJ genes (NOD_ShiLtJ_v1),
#  'mmnodshiltj_genomic_sequence': Mouse NOD/ShiLtJ sequences (NOD_ShiLtJ_v1),
#  'mmnzohlltj_gene_ensembl': Mouse NZO/HlLtJ genes (NZO_HlLtJ_v1),
#  'mmnzohlltj_genomic_sequence': Mouse NZO/HlLtJ sequences (NZO_HlLtJ_v1),
#  'mmonoceros_gene_ensembl': Narwhal genes (NGI_Narwhal_1),
#  'mmonoceros_genomic_sequence': Narwhal sequences (NGI_Narwhal_1),
#  'mmoschiferus_gene_ensembl': Siberian musk deer genes (MosMos_v2_BIUU_UCD),
#  'mmoschiferus_genomic_sequence': Siberian musk deer sequences (MosMos_v2_BIUU_UCD),
#  'mmpwkphj_gene_ensembl': Mouse PWK/PhJ genes (PWK_PhJ_v1),
#  'mmpwkphj_genomic_sequence': Mouse PWK/PhJ sequences (PWK_PhJ_v1),
#  'mmulatta_gene_ensembl': Macaque genes (Mmul_10),
#  'mmulatta_genomic_sequence': Macaque sequences (Mmul_10),
#  'mmulatta_snp': Macaque Short Variants (SNPs and indels excluding flagged variants) (Mmul_10),
#  'mmulatta_structvar': Macaque Structural Variants (Mmul_10),
#  'mmurdjan_gene_ensembl': Pinecone soldierfish genes (fMyrMur1.1),
#  'mmurdjan_genomic_sequence': Pinecone soldierfish sequences (fMyrMur1.1),
#  'mmurinus_gene_ensembl': Mouse Lemur genes (Mmur_3.0),
#  'mmurinus_genomic_sequence': Mouse Lemur sequences (Mmur_3.0),
#  'mmusculus_external_feature': Mouse Other Regulatory Regions (GRCm39),
#  'mmusculus_gene_ensembl': Mouse genes (GRCm39),
#  'mmusculus_genomic_sequence': Mouse sequences (GRCm39),
#  'mmusculus_karyotype_end': karyotype_end,
#  'mmusculus_karyotype_start': karyotype_start,
#  'mmusculus_mirna_target_feature': Mouse miRNA Target Regions (GRCm39),
#  'mmusculus_regulatory_feature': Mouse Regulatory Features (GRCm39),
#  'mmusculus_snp': Mouse Short Variants (SNPs and indels excluding flagged variants) (GRCm39),
#  'mmusculus_structvar': Mouse Structural Variants (GRCm39),
#  'mmwsbeij_gene_ensembl': Mouse WSB/EiJ genes (WSB_EiJ_v1),
#  'mmwsbeij_genomic_sequence': Mouse WSB/EiJ sequences (WSB_EiJ_v1),
#  'mnemestrina_gene_ensembl': Pig-tailed macaque genes (Mnem_1.0),
#  'mnemestrina_genomic_sequence': Pig-tailed macaque sequences (Mnem_1.0),
#  'mochrogaster_gene_ensembl': Prairie vole genes (MicOch1.0),
#  'mochrogaster_genomic_sequence': Prairie vole sequences (MicOch1.0),
#  'mpahari_gene_ensembl': Shrew mouse genes (PAHARI_EIJ_v1.1),
#  'mpahari_genomic_sequence': Shrew mouse sequences (PAHARI_EIJ_v1.1),
#  'mpfuro_gene_ensembl': Ferret genes (MusPutFur1.0),
#  'mpfuro_genomic_sequence': Ferret sequences (MusPutFur1.0),
#  'mspicilegus_gene_ensembl': Steppe mouse genes (MUSP714),
#  'mspicilegus_genomic_sequence': Steppe mouse sequences (MUSP714),
#  'mspretus_gene_ensembl': Algerian mouse genes (SPRET_EiJ_v1),
#  'mspretus_genomic_sequence': Algerian mouse sequences (SPRET_EiJ_v1),
#  'mzebra_gene_ensembl': Zebra mbuna genes (M_zebra_UMD2a),
#  'mzebra_genomic_sequence': Zebra mbuna sequences (M_zebra_UMD2a),
#  'nbrichardi_gene_ensembl': Lyretail cichlid genes (NeoBri1.0),
#  'nbrichardi_genomic_sequence': Lyretail cichlid sequences (NeoBri1.0),
#  'neugenii_gene_ensembl': Wallaby genes (Meug_1.0),
#  'neugenii_genomic_sequence': Wallaby sequences (Meug_1.0),
#  'nfurzeri_gene_ensembl': Turquoise killifish genes (Nfu_20140520),
#  'nfurzeri_genomic_sequence': Turquoise killifish sequences (Nfu_20140520),
#  'ngalili_gene_ensembl': Upper Galilee mountains blind mole rat genes (S.galili_v1.0),
#  'ngalili_genomic_sequence': Upper Galilee mountains blind mole rat sequences (S.galili_v1.0),
#  'nleucogenys_gene_ensembl': Gibbon genes (Nleu_3.0),
#  'nleucogenys_genomic_sequence': Gibbon sequences (Nleu_3.0),
#  'nleucogenys_snp': Gibbon Short Variants (SNPs and indels excluding flagged variants) (Nleu_3.0),
#  'nnaja_gene_ensembl': Indian cobra genes (Nana_v5),
#  'nnaja_genomic_sequence': Indian cobra sequences (Nana_v5),
#  'nscutatus_gene_ensembl': Mainland tiger snake genes (TS10Xv2-PRI),
#  'nscutatus_genomic_sequence': Mainland tiger snake sequences (TS10Xv2-PRI),
#  'nvison_gene_ensembl': American mink genes (NNQGG.v01),
#  'nvison_genomic_sequence': American mink sequences (NNQGG.v01),
#  'oanatinus_gene_ensembl': Platypus genes (mOrnAna1.p.v1),
#  'oanatinus_genomic_sequence': Platypus sequences (mOrnAna1.p.v1),
#  'oanatinus_snp': Platypus Short Variants (SNPs and indels excluding flagged variants) (mOrnAna1.p.v1),
#  'oarambouillet_gene_ensembl': Sheep genes (Oar_rambouillet_v1.0),
#  'oarambouillet_genomic_sequence': Sheep sequences (Oar_rambouillet_v1.0),
#  'oarambouillet_qtl_feature': qtl_feature,
#  'oarambouillet_snp': Sheep Short Variants (SNPs and indels excluding flagged variants) (Oar_rambouillet_v1.0),
#  'oarambouillet_structvar': Sheep Structural Variants (Oar_rambouillet_v1.0),
#  'oaries_gene_ensembl': Sheep (texel) genes (Oar_v3.1),
#  'oaries_genomic_sequence': Sheep (texel) sequences (Oar_v3.1),
#  'oaries_marker_end': marker_feature_end,
#  'oaries_marker_start': marker_feature,
#  'oaries_qtl_feature': qtl_feature,
#  'oaries_snp': Sheep (texel) Short Variants (SNPs and indels excluding flagged variants) (Oar_v3.1),
#  'oaries_structvar': Sheep (texel) Structural Variants (Oar_v3.1),
#  'ocuniculus_gene_ensembl': Rabbit genes (OryCun2.0),
#  'ocuniculus_genomic_sequence': Rabbit sequences (OryCun2.0),
#  'odegus_gene_ensembl': Degu genes (OctDeg1.0),
#  'odegus_genomic_sequence': Degu sequences (OctDeg1.0),
#  'ogarnettii_gene_ensembl': Bushbaby genes (OtoGar3),
#  'ogarnettii_genomic_sequence': Bushbaby sequences (OtoGar3),
#  'ojavanicus_gene_ensembl': Javanese ricefish genes (OJAV_1.1),
#  'ojavanicus_genomic_sequence': Javanese ricefish sequences (OJAV_1.1),
#  'okisutch_gene_ensembl': Coho salmon genes (Okis_V2),
#  'okisutch_genomic_sequence': Coho salmon sequences (Okis_V2),
#  'olatipes_gene_ensembl': Japanese medaka HdrR genes (ASM223467v1),
#  'olatipes_genomic_sequence': Japanese medaka HdrR sequences (ASM223467v1),
#  'omelastigma_gene_ensembl': Indian medaka genes (Om_v0.7.RACA),
#  'omelastigma_genomic_sequence': Indian medaka sequences (Om_v0.7.RACA),
#  'omykiss_gene_ensembl': Rainbow trout genes (USDA_OmykA_1.1),
#  'omykiss_genomic_sequence': Rainbow trout sequences (USDA_OmykA_1.1),
#  'oniloticus_gene_ensembl': Nile tilapia genes (O_niloticus_UMD_NMBU),
#  'oniloticus_genomic_sequence': Nile tilapia sequences (O_niloticus_UMD_NMBU),
#  'oprinceps_gene_ensembl': Pika genes (OchPri2.0-Ens),
#  'oprinceps_genomic_sequence': Pika sequences (OchPri2.0-Ens),
#  'osinensis_gene_ensembl': Chinese medaka genes (ASM858656v1),
#  'osinensis_genomic_sequence': Chinese medaka sequences (ASM858656v1),
#  'otshawytscha_gene_ensembl': Chinook salmon genes (Otsh_v1.0),
#  'otshawytscha_genomic_sequence': Chinook salmon sequences (Otsh_v1.0),
#  'pabelii_gene_ensembl': Sumatran orangutan genes (Susie_PABv2),
#  'pabelii_genomic_sequence': Sumatran orangutan sequences (Susie_PABv2),
#  'pabelii_snp': Sumatran orangutan Short Variants (SNPs and indels excluding flagged variants) (Susie_PABv2),
#  'panubis_gene_ensembl': Olive baboon genes (Panubis1.0),
#  'panubis_genomic_sequence': Olive baboon sequences (Panubis1.0),
#  'pcapensis_gene_ensembl': Hyrax genes (proCap1),
#  'pcapensis_genomic_sequence': Hyrax sequences (proCap1),
#  'pcatodon_gene_ensembl': Sperm whale genes (ASM283717v2),
#  'pcatodon_genomic_sequence': Sperm whale sequences (ASM283717v2),
#  'pcinereus_gene_ensembl': Koala genes (phaCin_unsw_v4.1),
#  'pcinereus_genomic_sequence': Koala sequences (phaCin_unsw_v4.1),
#  'pcoquereli_gene_ensembl': Coquerel's sifaka genes (Pcoq_1.0),
#  'pcoquereli_genomic_sequence': Coquerel's sifaka sequences (Pcoq_1.0),
#  'pformosa_gene_ensembl': Amazon molly genes (Poecilia_formosa-5.1.2),
#  'pformosa_genomic_sequence': Amazon molly sequences (Poecilia_formosa-5.1.2),
#  'pkingsleyae_gene_ensembl': Paramormyrops kingsleyae genes (PKINGS_0.1),
#  'pkingsleyae_genomic_sequence': Paramormyrops kingsleyae sequences (PKINGS_0.1),
#  'platipinna_gene_ensembl': Sailfin molly genes (P_latipinna-1.0),
#  'platipinna_genomic_sequence': Sailfin molly sequences (P_latipinna-1.0),
#  'pleo_gene_ensembl': Lion genes (PanLeo1.0),
#  'pleo_genomic_sequence': Lion sequences (PanLeo1.0),
#  'pmajor_gene_ensembl': Great Tit genes (Parus_major1.1),
#  'pmajor_genomic_sequence': Great Tit sequences (Parus_major1.1),
#  'pmarinus_gene_ensembl': Lamprey genes (Pmarinus_7.0),
#  'pmarinus_genomic_sequence': Lamprey sequences (Pmarinus_7.0),
#  'pmbairdii_gene_ensembl': Northern American deer mouse genes (HU_Pman_2.1),
#  'pmbairdii_genomic_sequence': Northern American deer mouse sequences (HU_Pman_2.1),
#  'pmuralis_gene_ensembl': Common wall lizard genes (PodMur_1.0),
#  'pmuralis_genomic_sequence': Common wall lizard sequences (PodMur_1.0),
#  'pnattereri_gene_ensembl': Red-bellied piranha genes (Pygocentrus_nattereri-1.0.2),
#  'pnattereri_genomic_sequence': Red-bellied piranha sequences (Pygocentrus_nattereri-1.0.2),
#  'pnyererei_gene_ensembl': Makobe Island cichlid genes (PunNye1.0),
#  'pnyererei_genomic_sequence': Makobe Island cichlid sequences (PunNye1.0),
#  'ppaniscus_gene_ensembl': Bonobo genes (panpan1.1),
#  'ppaniscus_genomic_sequence': Bonobo sequences (panpan1.1),
#  'ppardus_gene_ensembl': Leopard genes (PanPar1.0),
#  'ppardus_genomic_sequence': Leopard sequences (PanPar1.0),
#  'preticulata_gene_ensembl': Guppy genes (Guppy_female_1.0_MT),
#  'preticulata_genomic_sequence': Guppy sequences (Guppy_female_1.0_MT),
#  'psimus_gene_ensembl': Greater bamboo lemur genes (Prosim_1.0),
#  'psimus_genomic_sequence': Greater bamboo lemur sequences (Prosim_1.0),
#  'psinensis_gene_ensembl': Chinese softshell turtle genes (PelSin_1.0),
#  'psinensis_genomic_sequence': Chinese softshell turtle sequences (PelSin_1.0),
#  'psinus_gene_ensembl': Vaquita genes (mPhoSin1.pri),
#  'psinus_genomic_sequence': Vaquita sequences (mPhoSin1.pri),
#  'ptaltaica_gene_ensembl': Tiger genes (PanTig1.0),
#  'ptaltaica_genomic_sequence': Tiger sequences (PanTig1.0),
#  'ptextilis_gene_ensembl': Eastern brown snake genes (EBS10Xv2-PRI),
#  'ptextilis_genomic_sequence': Eastern brown snake sequences (EBS10Xv2-PRI),
#  'ptroglodytes_gene_ensembl': Chimpanzee genes (Pan_tro_3.0),
#  'ptroglodytes_genomic_sequence': Chimpanzee sequences (Pan_tro_3.0),
#  'ptroglodytes_snp': Chimpanzee Short Variants (SNPs and indels excluding flagged variants) (Pan_tro_3.0),
#  'pvampyrus_gene_ensembl': Megabat genes (pteVam1),
#  'pvampyrus_genomic_sequence': Megabat sequences (pteVam1),
#  'rbieti_gene_ensembl': Black snub-nosed monkey genes (ASM169854v1),
#  'rbieti_genomic_sequence': Black snub-nosed monkey sequences (ASM169854v1),
#  'rferrumequinum_gene_ensembl': Greater horseshoe bat genes (mRhiFer1_v1.p),
#  'rferrumequinum_genomic_sequence': Greater horseshoe bat sequences (mRhiFer1_v1.p),
#  'rnorvegicus_gene_ensembl': Rat genes (mRatBN7.2),
#  'rnorvegicus_genomic_sequence': Rat sequences (mRatBN7.2),
#  'rnorvegicus_karyotype_end': karyotype_end,
#  'rnorvegicus_karyotype_start': karyotype_start,
#  'rnorvegicus_qtl_feature': qtl_feature,
#  'rnorvegicus_snp': Rat Short Variants (SNPs and indels excluding flagged variants) (mRatBN7.2),
#  'rroxellana_gene_ensembl': Golden snub-nosed monkey genes (Rrox_v1),
#  'rroxellana_genomic_sequence': Golden snub-nosed monkey sequences (Rrox_v1),
#  'saraneus_gene_ensembl': Shrew genes (sorAra1),
#  'saraneus_genomic_sequence': Shrew sequences (sorAra1),
#  'saurata_gene_ensembl': Gilthead seabream genes (fSpaAur1.1),
#  'saurata_genomic_sequence': Gilthead seabream sequences (fSpaAur1.1),
#  'sbboliviensis_gene_ensembl': Bolivian squirrel monkey genes (SaiBol1.0),
#  'sbboliviensis_genomic_sequence': Bolivian squirrel monkey sequences (SaiBol1.0),
#  'scanaria_gene_ensembl': Common canary genes (SCA1),
#  'scanaria_genomic_sequence': Common canary sequences (SCA1),
#  'scaustralis_gene_ensembl': African ostrich genes (ASM69896v1),
#  'scaustralis_genomic_sequence': African ostrich sequences (ASM69896v1),
#  'scerevisiae_gene_ensembl': Saccharomyces cerevisiae genes (R64-1-1),
#  'scerevisiae_genomic_sequence': Saccharomyces cerevisiae sequences (R64-1-1),
#  'scerevisiae_snp': Saccharomyces cerevisiae Short Variants (SNPs and indels excluding flagged variants) (R64-1-1),
#  'sdumerili_gene_ensembl': Greater amberjack genes (Sdu_1.0),
#  'sdumerili_genomic_sequence': Greater amberjack sequences (Sdu_1.0),
#  'sformosus_gene_ensembl': Asian bonytongue genes (fSclFor1.1),
#  'sformosus_genomic_sequence': Asian bonytongue sequences (fSclFor1.1),
#  'sgrahami_gene_ensembl': Golden-line barbel genes (SAMN03320097.WGS_v1.1),
#  'sgrahami_genomic_sequence': Golden-line barbel sequences (SAMN03320097.WGS_v1.1),
#  'shabroptila_gene_ensembl': Kakapo genes (bStrHab1_v1.p),
#  'shabroptila_genomic_sequence': Kakapo sequences (bStrHab1_v1.p),
#  'sharrisii_gene_ensembl': Tasmanian devil genes (mSarHar1.11),
#  'sldorsalis_gene_ensembl': Yellowtail amberjack genes (Sedor1),
#  'sldorsalis_genomic_sequence': Yellowtail amberjack sequences (Sedor1),
#  'slucioperca_gene_ensembl': Pike-perch genes (SLUC_FBN_1),
#  'slucioperca_genomic_sequence': Pike-perch sequences (SLUC_FBN_1),
#  'smaximus_gene_ensembl': Turbot genes (ASM1334776v1),
#  'smaximus_genomic_sequence': Turbot sequences (ASM1334776v1),
#  'smerianae_gene_ensembl': Argentine black and white tegu genes (HLtupMer3),
#  'smerianae_genomic_sequence': Argentine black and white tegu sequences (HLtupMer3),
#  'spartitus_gene_ensembl': Bicolor damselfish genes (Stegastes_partitus-1.0.2),
#  'spartitus_genomic_sequence': Bicolor damselfish sequences (Stegastes_partitus-1.0.2),
#  'spunctatus_gene_ensembl': Tuatara genes (ASM311381v1),
#  'spunctatus_genomic_sequence': Tuatara sequences (ASM311381v1),
#  'ssalar_gene_ensembl': Atlantic salmon genes (Ssal_v3.1),
#  'ssalar_genomic_sequence': Atlantic salmon sequences (Ssal_v3.1),
#  'ssbamei_gene_ensembl': Pig - Bamei genes (Bamei_pig_v1),
#  'ssbamei_genomic_sequence': Pig - Bamei sequences (Bamei_pig_v1),
#  'ssberkshire_gene_ensembl': Pig - Berkshire genes (Berkshire_pig_v1),
#  'ssberkshire_genomic_sequence': Pig - Berkshire sequences (Berkshire_pig_v1),
#  'sscrofa_gene_ensembl': Pig - Duroc genes (Sscrofa11.1),
#  'sscrofa_genomic_sequence': Pig - Duroc sequences (Sscrofa11.1),
#  'sscrofa_qtl_feature': qtl_feature,
#  'sscrofa_snp': Pig - Duroc Short Variants (SNPs and indels excluding flagged variants) (Sscrofa11.1),
#  'sscrofa_structvar': Pig - Duroc Structural Variants (Sscrofa11.1),
#  'sshampshire_gene_ensembl': Pig - Hampshire genes (Hampshire_pig_v1),
#  'sshampshire_genomic_sequence': Pig - Hampshire sequences (Hampshire_pig_v1),
#  'ssjinhua_gene_ensembl': Pig - Jinhua genes (Jinhua_pig_v1),
#  'ssjinhua_genomic_sequence': Pig - Jinhua sequences (Jinhua_pig_v1),
#  'sslandrace_gene_ensembl': Pig - Landrace genes (Landrace_pig_v1),
#  'sslandrace_genomic_sequence': Pig - Landrace sequences (Landrace_pig_v1),
#  'sslargewhite_gene_ensembl': Pig - Largewhite genes (Large_White_v1),
#  'sslargewhite_genomic_sequence': Pig - Largewhite sequences (Large_White_v1),
#  'ssmeishan_gene_ensembl': Pig - Meishan genes (Meishan_pig_v1),
#  'ssmeishan_genomic_sequence': Pig - Meishan sequences (Meishan_pig_v1),
#  'sspietrain_gene_ensembl': Pig - Pietrain genes (Pietrain_pig_v1),
#  'sspietrain_genomic_sequence': Pig - Pietrain sequences (Pietrain_pig_v1),
#  'ssrongchang_gene_ensembl': Pig - Rongchang genes (Rongchang_pig_v1),
#  'ssrongchang_genomic_sequence': Pig - Rongchang sequences (Rongchang_pig_v1),
#  'sstibetan_gene_ensembl': Pig - Tibetan genes (Tibetan_Pig_v2),
#  'sstibetan_genomic_sequence': Pig - Tibetan sequences (Tibetan_Pig_v2),
#  'ssusmarc_gene_ensembl': Pig USMARC genes (USMARCv1.0),
#  'ssusmarc_genomic_sequence': Pig USMARC sequences (USMARCv1.0),
#  'sswuzhishan_gene_ensembl': Pig - Wuzhishan genes (minipig_v1.0),
#  'sswuzhishan_genomic_sequence': Pig - Wuzhishan sequences (minipig_v1.0),
#  'strutta_gene_ensembl': Brown trout genes (fSalTru1.1),
#  'strutta_genomic_sequence': Brown trout sequences (fSalTru1.1),
#  'svulgaris_gene_ensembl': Eurasian red squirrel genes (mSciVul1.1),
#  'svulgaris_genomic_sequence': Eurasian red squirrel sequences (mSciVul1.1),
#  'tbelangeri_gene_ensembl': Tree Shrew genes (tupBel1),
#  'tbelangeri_genomic_sequence': Tree Shrew sequences (tupBel1),
#  'tctriunguis_gene_ensembl': Three-toed box turtle genes (T_m_triunguis-2.0),
#  'tctriunguis_genomic_sequence': Three-toed box turtle sequences (T_m_triunguis-2.0),
#  'tguttata_gene_ensembl': Zebra finch genes (bTaeGut1_v1.p),
#  'tguttata_genomic_sequence': Zebra finch sequences (bTaeGut1_v1.p),
#  'tguttata_snp': Zebra finch Short Variants (SNPs and indels excluding flagged variants) (bTaeGut1_v1.p),
#  'tnigroviridis_gene_ensembl': Tetraodon genes (TETRAODON 8.0),
#  'tnigroviridis_genomic_sequence': Tetraodon sequences (TETRAODON 8.0),
#  'tnigroviridis_snp': Tetraodon Short Variants (SNPs and indels excluding flagged variants) (TETRAODON 8.0),
#  'trubripes_gene_ensembl': Fugu genes (fTakRub1.2),
#  'trubripes_genomic_sequence': Fugu sequences (fTakRub1.2),
#  'ttruncatus_gene_ensembl': Dolphin genes (turTru1),
#  'ttruncatus_genomic_sequence': Dolphin sequences (turTru1),
#  'uamericanus_gene_ensembl': American black bear genes (ASM334442v1),
#  'uamericanus_genomic_sequence': American black bear sequences (ASM334442v1),
#  'umaritimus_gene_ensembl': Polar bear genes (UrsMar_1.0),
#  'umaritimus_genomic_sequence': Polar bear sequences (UrsMar_1.0),
#  'uparryii_gene_ensembl': Arctic ground squirrel genes (ASM342692v1),
#  'uparryii_genomic_sequence': Arctic ground squirrel sequences (ASM342692v1),
#  'vpacos_gene_ensembl': Alpaca genes (vicPac1),
#  'vpacos_genomic_sequence': Alpaca sequences (vicPac1),
#  'vursinus_gene_ensembl': Common wombat genes (bare-nosed_wombat_genome_assembly),
#  'vursinus_genomic_sequence': Common wombat sequences (bare-nosed_wombat_genome_assembly),
#  'vvulpes_gene_ensembl': Red fox genes (VulVul2.2),
#  'vvulpes_genomic_sequence': Red fox sequences (VulVul2.2),
#  'xmaculatus_gene_ensembl': Platyfish genes (X_maculatus-5.0-male),
#  'xmaculatus_genomic_sequence': Platyfish sequences (X_maculatus-5.0-male),
#  'xtropicalis_gene_ensembl': Tropical clawed frog genes (UCB_Xtro_10.0),
#  'xtropicalis_genomic_sequence': Tropical clawed frog sequences (UCB_Xtro_10.0)}

# %%
miRNA_marg = server.datasets['hsapiens_mirna_target_feature']

# %%
from biomart import BiomartDataset

interpro = BiomartDataset("http://uswest.ensembl.org/biomart", name = 'entry' )

response = interpro.search({
'filters': { 'entry_id': 'Q9Y6C9' },
'attributes': [ 'entry_name', 'abstract' ]
})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [83], line 5
#       1 from biomart import BiomartDataset
#       3 interpro = BiomartDataset("http://uswest.ensembl.org/biomart", name = 'entry' )
# ----> 5 response = interpro.search({
#       6 'filters': { 'entry_id': 'Q9Y6C9' },
#       7 'attributes': [ 'entry_name', 'abstract' ]
#       8 })
#
# File S:\Miniconda\lib\site-packages\biomart\dataset.py:166, in BiomartDataset.search(self, params, header, count)
#     164 # check filters
#     165 for filter_name, filter_value in filters.items():
# --> 166     dataset_filter = self.filters.get(filter_name, None)
#     168     if not dataset_filter:
#     169         if self.verbose:
#
# File S:\Miniconda\lib\site-packages\biomart\dataset.py:64, in BiomartDataset.filters(self)
#      61 @property
#      62 def filters(self):
#      63     if not self._filters:
# ---> 64         self.fetch_filters()
#      65     return self._filters
#
# File S:\Miniconda\lib\site-packages\biomart\dataset.py:87, in BiomartDataset.fetch_filters(self)
#      83     if line:
#      84         line = line.split("\t")
#      85         self._filters[line[0]] = biomart.BiomartFilter(
#      86             name = line[0],
# ---> 87             display_name = line[1],
#      88             accepted_values = line[2],
#      89             filter_type = line[5],
#      90         )
#      93 # retrieve additional filters from the dataset configuration page
#      94 r = self.server.get_request(type="configuration", dataset=self.name)
#
# IndexError: list index out of range

# %% [markdown]
# ##### 5.6.2 goenrich

# %%
import goenrich
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import goenrich
#
# ModuleNotFoundError: No module named 'goenrich'

# %%
h9_background = load_large_dataFrame("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/total_h9_htg_geneset.convert_id.csv")
h9_htg_homo_top10pct = load_large_dataFrame("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/homo_10pct_h9_htg_geneset.convert_id.csv")
h9_htg_homo_top25pct = load_large_dataFrame("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/homo_25pct_h9_htg_geneset.convert_id.csv")
h9_htg_homo_top75pct = load_large_dataFrame("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/homo_75pct_h9_htg_geneset.convert_id.csv")
h9_htg_homo_top90pct = load_large_dataFrame("../Current_Data/05.Gene_Heterogeneity/Go_enrichment/homo_90pct_h9_htg_geneset.convert_id.csv")

# %%
# build the ontology
O = goenrich.obo.ontology('../../../../FigureFactory/Gene_Ontology_Enrichment/GO_db/go-basic.obo')
# use all entrez geneid associations form gene2go as background
# use annot = goenrich.read.goa('db/gene_association.goa_human.gaf.gz') for uniprot
# use annot = goenrich.read.sgd('db/gene_association.sgd.gz') for yeast
gene2go = goenrich.read.gene2go('../../../../FigureFactory/Gene_Ontology_Enrichment/GO_db/gene2go.gz')

# propagate the background through the ontology
values = {k: set(v) for k,v in gene2go.groupby('GO_ID')['GeneID']}
background_attribute = 'gene2go'
goenrich.enrich.propagate(O, values, background_attribute)

# propagate the custom background through the ontology
# values = {}
# for k,v in gene2go.groupby('GO_ID')['GeneID']:
#     concat_lst = []
#     for v_gene in v:
#         if v_gene in h9_background['ENTREZID']:
#             concat_lst.append(v_gene)
#     if len(concat_lst) >= 1:
#         values[k] = set(concat_lst)
#     else:
#         pass
#background_attribute = 'custom'
background_attribute = 'gene2go'
goenrich.enrich.propagate(O, values, background_attribute)

# %%
# extract some list of entries as example query
# use query = annot['db_object_symbol'].unique()[:20]
# query = gene2go['GeneID'].unique()[:20]
query = h9_htg_homo_top75pct['ENTREZID'].unique()
#query = h9_htg_homo_top75pct['ENTREZID'].unique()
#query = h9_htg_homo_top75pct['ENTREZID'].unique()
#query = h9_htg_homo_top75pct['ENTREZID'].unique()

#query

# %%
# for additional export to graphviz just specify the gvfile argument
# the show argument keeps the graph reasonably small
df = goenrich.enrich.analyze(O, query, background_attribute, gvfile='test.dot')
df
# Out:
#              term   q  rejected   p   x     n      M    N  \
# 0      GO:0000001 NaN       NaN NaN   0     0  20739  288
# 1      GO:0000002 NaN       NaN NaN   0    27  20739  288
# 2      GO:0000003 NaN       NaN NaN  33  1447  20739  288
# 3      GO:0000006 NaN       NaN NaN   0     0  20739  288
# 4      GO:0000007 NaN       NaN NaN   0     0  20739  288
# ...           ...  ..       ...  ..  ..   ...    ...  ...
# 43330  GO:2001313 NaN       NaN NaN   0     0  20739  288
# 43331  GO:2001314 NaN       NaN NaN   0     0  20739  288
# 43332  GO:2001315 NaN       NaN NaN   0     0  20739  288
# 43333  GO:2001316 NaN       NaN NaN   0     0  20739  288
# 43334  GO:2001317 NaN       NaN NaN   0     0  20739  288
#
#                                                     name           namespace
# 0                              mitochondrion inheritance  biological_process
# 1                       mitochondrial genome maintenance  biological_process
# 2                                           reproduction  biological_process
# 3      high-affinity zinc transmembrane transporter a...  molecular_function
# 4      low-affinity zinc ion transmembrane transporte...  molecular_function
# ...                                                  ...                 ...
# 43330  UDP-4-deoxy-4-formamido-beta-L-arabinopyranose...  biological_process
# 43331  UDP-4-deoxy-4-formamido-beta-L-arabinopyranose...  biological_process
# 43332  UDP-4-deoxy-4-formamido-beta-L-arabinopyranose...  biological_process
# 43333                       kojic acid metabolic process  biological_process
# 43334                    kojic acid biosynthetic process  biological_process
#
# [43335 rows x 10 columns]

# %%
df.loc[(df['q']<0.05)].sort_values('q').iloc[0:29]
# Out:
#              term             q  rejected             p   x    n      M    N  \
# 32762  GO:0098798  1.774313e-12       1.0  2.267203e-16  29  300  20739  288
# 4253   GO:0006412  4.488858e-11       1.0  1.147165e-14  30  375  20739  288
# 18801  GO:0043043  2.138465e-10       1.0  8.197542e-14  30  404  20739  288
# 3749   GO:0005759  2.746463e-09       1.0  1.403763e-12  31  482  20739  288
# 3736   GO:0005743  5.404603e-09       1.0  3.452979e-12  31  499  20739  288
# 40242  GO:1904813  2.245097e-06       1.0  2.008137e-09  14  124  20739  288
# 24679  GO:0051082  2.245097e-06       1.0  2.008137e-09  14  124  20739  288
# 11693  GO:0022613  3.305083e-06       1.0  3.378567e-09  26  477  20739  288
# 19905  GO:0044389  3.862858e-06       1.0  4.442336e-09  21  319  20739  288
# 363    GO:0000502  6.022116e-06       1.0  7.868153e-09  10   59  20739  288
# 13087  GO:0031625  6.022116e-06       1.0  8.464513e-09  20  300  20739  288
# 35102  GO:0140053  7.048377e-06       1.0  1.080763e-08  14  141  20739  288
# 4023   GO:0006091  8.718477e-06       1.0  1.448252e-08  23  407  20739  288
# 5295   GO:0008135  1.468593e-05       1.0  2.627180e-08  11   85  20739  288
# 40301  GO:1904874  1.600410e-05       1.0  3.067487e-08   6   15  20739  288
# 13932  GO:0032543  1.767003e-05       1.0  4.289938e-08  12  110  20739  288
# 3751   GO:0005761  1.767003e-05       1.0  4.281412e-08  11   89  20739  288
# 29809  GO:0071826  1.767003e-05       1.0  4.182355e-08  17  238  20739  288
# 209    GO:0000313  1.767003e-05       1.0  4.281412e-08  11   89  20739  288
# 32764  GO:0098800  1.815628e-05       1.0  4.639991e-08  14  158  20739  288
# 33252  GO:0101002  1.873145e-05       1.0  5.026328e-08  15  185  20739  288
# 19907  GO:0044391  2.213852e-05       1.0  6.223452e-08  15  188  20739  288
# 40299  GO:1904872  3.438769e-05       1.0  1.098508e-07   6   18  20739  288
# 3693   GO:0005681  3.438769e-05       1.0  1.078553e-07  15  196  20739  288
# 5993   GO:0009055  3.438769e-05       1.0  1.035805e-07  12  119  20739  288
# 11698  GO:0022618  4.557157e-05       1.0  1.514006e-07  16  230  20739  288
# 8655   GO:0015980  4.763572e-05       1.0  1.678731e-07  17  262  20739  288
# 3811   GO:0005840  4.763572e-05       1.0  1.704319e-07  16  232  20739  288
# 3810   GO:0005839  6.046413e-05       1.0  2.240557e-07   6   20  20739  288
#
#                                                     name           namespace
# 32762           mitochondrial protein-containing complex  cellular_component
# 4253                                         translation  biological_process
# 18801                       peptide biosynthetic process  biological_process
# 3749                                mitochondrial matrix  cellular_component
# 3736                        mitochondrial inner membrane  cellular_component
# 40242                       ficolin-1-rich granule lumen  cellular_component
# 24679                           unfolded protein binding  molecular_function
# 11693               ribonucleoprotein complex biogenesis  biological_process
# 19905              ubiquitin-like protein ligase binding  molecular_function
# 363                                   proteasome complex  cellular_component
# 13087                   ubiquitin protein ligase binding  molecular_function
# 35102                      mitochondrial gene expression  biological_process
# 4023      generation of precursor metabolites and energy  biological_process
# 5295            translation factor activity, RNA binding  molecular_function
# 40301  positive regulation of telomerase RNA localiza...  biological_process
# 13932                          mitochondrial translation  biological_process
# 3751                              mitochondrial ribosome  cellular_component
# 29809     ribonucleoprotein complex subunit organization  biological_process
# 209                                  organellar ribosome  cellular_component
# 32764       inner mitochondrial membrane protein complex  cellular_component
# 33252                             ficolin-1-rich granule  cellular_component
# 19907                                  ribosomal subunit  cellular_component
# 40299  regulation of telomerase RNA localization to C...  biological_process
# 3693                                spliceosomal complex  cellular_component
# 5993                          electron transfer activity  molecular_function
# 11698                 ribonucleoprotein complex assembly  biological_process
# 8655   energy derivation by oxidation of organic comp...  biological_process
# 3811                                            ribosome  cellular_component
# 3810                             proteasome core complex  cellular_component

# %%
h9_background.loc[h9_background['ENTREZID'].isin([x for x in query if x in values['GO:0006412']])]
# Out:
#       SYMBOL  ENTREZID
# 539   MRPL11     65003
# 544   MRPL23      6150
# 548   MRPL36     64979
# 555   MRPS15     64960
# 557  MRPS18C     51023
# 868     RPL4      6124
# 874     RPL8      6132
# 885   RPS15A      6210

# %%
h9_background
# Out:
#        SYMBOL  ENTREZID
# 1       AARS1        16
# 15      ACAA2     10449
# 16      ACAT2        39
# 17      ACIN1     22985
# 18       ACLY        47
# ...       ...       ...
# 1176   ZNHIT1     10467
# 1177    ZNRD2     10534
# 1178   ZRANB2      9406
# 1179  ZSCAN10     84891
# 1180      ZYX      7791
#
# [1147 rows x 2 columns]
